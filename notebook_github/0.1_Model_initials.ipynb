# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat, savemat
import pandas as pd
import scipy.special as SS
import scipy.stats as SSA
import copy
import random
import math

# %%
colours = {0.01:'red',0.1:'purple',0.5:'darkviolet',1:'black',5:'blue',10:'cornflowerblue','inf':'skyblue','geo':'grey'}

# %%
x_cutoff = 100
R0 = 2.5  ## the model input
plt.figure(dpi=450,figsize=(6,4))
for r,c in colours.items():
    weights = np.zeros(x_cutoff)
    if r == 'inf':
        for i in range(x_cutoff):
            temp1=SSA.poisson.pmf(i,R0)
            weights[i] = temp1
        weights_n = weights/np.sum(weights)
        plt.plot(range(100),weights_n,label=r'r={}'.format(r),color=c)
#     r = 50 ## parameters (in the paper of Lloyd smith is the k) 0.1 to start 
    elif r== 'geo':
        for i in range(x_cutoff):
            p = 1/(R0+1)
            temp1= p*np.power((1-p),i)
            weights[i] = temp1
        weights_n = weights/np.sum(weights)
        plt.plot(range(100),weights_n,label=r'r={}'.format(r),color=c,ls='--')
    else:
        p = r/(R0+r)
        for i in range(x_cutoff):
            temp1=SS.gamma(r+i)/SS.gamma(r)/SS.gamma((i+1))*np.power(p,r)*np.power((1-p),i)
            weights[i] = temp1
        weights_n = weights/np.sum(weights)
        plt.plot(range(100),weights_n,label=r'r={}'.format(r),color=c)
    print('it covers', np.sum(weights)*100,'% of the values') ## to generate the sample, the sum up probe should be 1
    ## we can assign/compare the rest of prob to each one
    prob_res = (1- np.sum(weights))/x_cutoff
    print (prob_res, 'compare with the last prob', weights[-1])
    ## normalise the weights to 1

plt.legend()
plt.yscale('log')
plt.ylim(0.0000001,1.2)
plt.xlim(0.,100)
plt.xlabel('x')
plt.ylabel(r'$P_{n}$')
plt.show()
# Out:
# it covers 99.29040524284376 % of the values
# 7.0959475715624e-05 compare with the last prob 6.778543241544144e-05
# it covers 99.94793690833258 % of the values
# 5.206309166742029e-06 compare with the last prob 2.4979978105066747e-05
# it covers 99.99999983719292 % of the values
# 1.628070789294611e-11 compare with the last prob 3.349963947497101e-10
# it covers 99.99999999999976 % of the values
# 2.4424906541753444e-17 compare with the last prob 9.755654775956703e-16
# it covers 100.0 % of the values
# 0.0 compare with the last prob 3.3891205435755526e-42
# it covers 100.0 % of the values
# 0.0 compare with the last prob 2.6619580973154302e-58
# it covers 100.0 % of the values
# 0.0 compare with the last prob 2.189379256792208e-118
# it covers 99.99999999999976 % of the values
# 2.4424906541753444e-17 compare with the last prob 9.755654775956703e-16

# %%
x_cutoff = 600
R0 = 2.5  ## the model input
plt.figure(dpi=600,figsize=(4.,2.7))
for r,c in colours.items():
    weights = np.zeros(x_cutoff)
    if r == 'inf':
        for i in range(x_cutoff):
            temp1=SSA.poisson.pmf(i,R0)
            weights[i] = temp1
        weights_n = weights/np.sum(weights)
        plt.plot(range(x_cutoff),weights_n,label=r'r={}'.format(r),color=c)
#     r = 50 ## parameters (in the paper of Lloyd smith is the k) 0.1 to start 
    elif r== 'geo':
        for i in range(x_cutoff):
            p = 1/(R0+1)
            temp1= p*np.power((1-p),i)
            weights[i] = temp1
        weights_n = weights/np.sum(weights)
        plt.plot(range(x_cutoff),weights_n,label=r'r={}'.format(r),color=c,ls='--')
    else:
        p = r/(R0+r)
        for i in range(x_cutoff):
            temp1 = SSA.nbinom.pmf(i, r, p)
#             temp1=SS.gamma(r+i)/SS.gamma(r)/SS.gamma((i+1))*np.power(p,r)*np.power((1-p),i)
            weights[i] = temp1
        weights_n = weights/np.sum(weights)
        plt.plot(range(x_cutoff),weights_n,label=r'r={}'.format(r),color=c)
    print('it covers', np.sum(weights)*100,'% of the values') ## to generate the sample, the sum up probe should be 1
    ## we can assign/compare the rest of prob to each one
    prob_res = (1- np.sum(weights))/x_cutoff
    print (prob_res, 'compare with the last prob', weights[-1])
    ## normalise the weights to 1

plt.legend(ncol=2,frameon=False)
plt.yscale('log')
plt.ylim(0.0000001,1.2)
plt.xlim(0.,100)
plt.xlabel('x',size=12)
plt.ylabel(r'$P_{n}$',size=12)
plt.tight_layout()
# plt.show()
plt.savefig('pn_r.pdf')
# Out:
# it covers 99.97081075110923 % of the values
# 4.864874815128465e-07 compare with the last prob 1.5499740082466866e-06
# it covers 99.99999999996373 % of the values
# 6.045164369083978e-16 compare with the last prob 1.5047868154941983e-14
# it covers 100.0 % of the values
# 0.0 compare with the last prob 3.499282587258397e-50
# it covers 99.99999999999997 % of the values
# 5.551115123125783e-19 compare with the last prob 8.418574981829838e-89
# it covers 99.99999999999999 % of the values
# 1.8503717077085944e-19 compare with the last prob 1.1498479405819008e-277
# it covers 100.00000000000003 % of the values
# -3.7007434154171887e-19 compare with the last prob 0.0
# it covers 100.0 % of the values
# 0.0 compare with the last prob 0.0
# it covers 100.0 % of the values
# 0.0 compare with the last prob 8.418574981829409e-89

# %%
x_cutoff = 100
R0 = 2.5  ## the model input
plt.figure(dpi=450,figsize=(6,4))
for r in np.arange(0.01, 1, 0.08):
    weights = np.zeros(x_cutoff)

    p = r/(R0+r)
    for i in range(x_cutoff):
        temp1=SS.gamma(r+i)/SS.gamma(r)/SS.gamma((i+1))*np.power(p,r)*np.power((1-p),i)
        weights[i] = temp1
    weights_n = weights/np.sum(weights)
    plt.plot(range(100),weights_n,label=r'r={}'.format(r))
    print('it covers', np.sum(weights)*100,'% of the values') ## to generate the sample, the sum up probe should be 1
    ## we can assign/compare the rest of prob to each one
    prob_res = (1- np.sum(weights))/x_cutoff
    print (prob_res, 'compare with the last prob', weights[-1])
    ## normalise the weights to 1

plt.legend()
# plt.yscale('log')
plt.ylim(0.0000001,1.2)
plt.xlim(0.,25)
plt.xlabel('x')
plt.ylabel('probability')
plt.show()
# Out:
# it covers 99.29040524284376 % of the values
# 7.0959475715624e-05 compare with the last prob 6.778543241544144e-05
# it covers 99.9270404807852 % of the values
# 7.2959519214810254e-06 compare with the last prob 3.2054675051602224e-05
# it covers 99.9950543028844 % of the values
# 4.945697115599224e-07 compare with the last prob 3.757839976311119e-06
# it covers 99.9996425329754 % of the values
# 3.5746702460315304e-08 compare with the last prob 3.8481936487406367e-07
# it covers 99.99997196810665 % of the values
# 2.8031893350988214e-09 compare with the last prob 3.900692004741917e-08
# it covers 99.99999761832275 % of the values
# 2.3816772443119304e-10 compare with the last prob 4.061815356441179e-09
# it covers 99.99999978164664 % of the values
# 2.1835336871944834e-11 compare with the last prob 4.407553248211201e-10
# it covers 99.99999997849223 % of the values
# 2.1507773340090352e-12 compare with the last prob 5.0133359006785427e-11
# it covers 99.99999999773327 % of the values
# 2.266731247146936e-13 compare with the last prob 5.990337234442738e-12
# it covers 99.9999999997454 % of the values
# 2.5460744623728716e-14 compare with the last prob 7.521875321775308e-13
# it covers 99.9999999999696 % of the values
# 3.0397906414236785e-15 compare with the last prob 9.919652335053914e-14
# it covers 99.99999999999613 % of the values
# 3.8635761256955447e-16 compare with the last prob 1.3724241946275518e-14
# it covers 99.99999999999947 % of the values
# 5.2180482157382354e-17 compare with the last prob 1.9893552583382875e-15
