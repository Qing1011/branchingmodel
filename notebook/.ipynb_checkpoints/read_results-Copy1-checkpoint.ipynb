# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat, savemat
import pandas as pd
import scipy.special as SS
import scipy.stats as SSA
import copy
import random
import math
from sklearn.model_selection import ParameterGrid
import os
import numpy.linalg as LA
import gzip

# load pickle module
import pickle

# %%
rs = np.arange(0.01, 1, 0.02)

R0s = np.arange(1.5, 6.5, 0.1)

param_grid = {'R0': R0s, 'r' : rs}

grid = ParameterGrid(param_grid)

para_dict = list(grid)

# %%
file_dir = '../../../../../../Volumes/My Passport/branching/branching_results/'

# %%
para_dict[0]
# Out:
# {'R0': 1.5, 'r': 0.01}

# %%
file_name
# Out:
# '../../../../../../Volumes/My Passport/branching/branching_results/NewInf_R0-3.4_r-0.99_499.npy.gz'

# %%
R0s = np.arange(1.5, 3.5, 0.1)

# %%
len(rs)
# Out:
# 50

# %%
para_dict[:1000]
# Out:
# [{'R0': 1.5, 'r': 0.01},
#  {'R0': 1.5, 'r': 0.03},
#  {'R0': 1.5, 'r': 0.049999999999999996},
#  {'R0': 1.5, 'r': 0.06999999999999999},
#  {'R0': 1.5, 'r': 0.08999999999999998},
#  {'R0': 1.5, 'r': 0.10999999999999997},
#  {'R0': 1.5, 'r': 0.12999999999999998},
#  {'R0': 1.5, 'r': 0.15},
#  {'R0': 1.5, 'r': 0.16999999999999998},
#  {'R0': 1.5, 'r': 0.18999999999999997},
#  {'R0': 1.5, 'r': 0.20999999999999996},
#  {'R0': 1.5, 'r': 0.22999999999999998},
#  {'R0': 1.5, 'r': 0.24999999999999997},
#  {'R0': 1.5, 'r': 0.26999999999999996},
#  {'R0': 1.5, 'r': 0.29},
#  {'R0': 1.5, 'r': 0.30999999999999994},
#  {'R0': 1.5, 'r': 0.32999999999999996},
#  {'R0': 1.5, 'r': 0.35},
#  {'R0': 1.5, 'r': 0.36999999999999994},
#  {'R0': 1.5, 'r': 0.38999999999999996},
#  {'R0': 1.5, 'r': 0.4099999999999999},
#  {'R0': 1.5, 'r': 0.42999999999999994},
#  {'R0': 1.5, 'r': 0.44999999999999996},
#  {'R0': 1.5, 'r': 0.4699999999999999},
#  {'R0': 1.5, 'r': 0.48999999999999994},
#  {'R0': 1.5, 'r': 0.5099999999999999},
#  {'R0': 1.5, 'r': 0.5299999999999999},
#  {'R0': 1.5, 'r': 0.5499999999999999},
#  {'R0': 1.5, 'r': 0.57},
#  {'R0': 1.5, 'r': 0.59},
#  {'R0': 1.5, 'r': 0.6099999999999999},
#  {'R0': 1.5, 'r': 0.6299999999999999},
#  {'R0': 1.5, 'r': 0.6499999999999999},
#  {'R0': 1.5, 'r': 0.6699999999999999},
#  {'R0': 1.5, 'r': 0.69},
#  {'R0': 1.5, 'r': 0.7099999999999999},
#  {'R0': 1.5, 'r': 0.7299999999999999},
#  {'R0': 1.5, 'r': 0.7499999999999999},
#  {'R0': 1.5, 'r': 0.7699999999999999},
#  {'R0': 1.5, 'r': 0.7899999999999999},
#  {'R0': 1.5, 'r': 0.8099999999999998},
#  {'R0': 1.5, 'r': 0.8299999999999998},
#  {'R0': 1.5, 'r': 0.8499999999999999},
#  {'R0': 1.5, 'r': 0.8699999999999999},
#  {'R0': 1.5, 'r': 0.8899999999999999},
#  {'R0': 1.5, 'r': 0.9099999999999999},
#  {'R0': 1.5, 'r': 0.9299999999999998},
#  {'R0': 1.5, 'r': 0.9499999999999998},
#  {'R0': 1.5, 'r': 0.9699999999999999},
#  {'R0': 1.5, 'r': 0.9899999999999999},
#  {'R0': 1.6, 'r': 0.01},
#  {'R0': 1.6, 'r': 0.03},
#  {'R0': 1.6, 'r': 0.049999999999999996},
#  {'R0': 1.6, 'r': 0.06999999999999999},
#  {'R0': 1.6, 'r': 0.08999999999999998},
#  {'R0': 1.6, 'r': 0.10999999999999997},
#  {'R0': 1.6, 'r': 0.12999999999999998},
#  {'R0': 1.6, 'r': 0.15},
#  {'R0': 1.6, 'r': 0.16999999999999998},
#  {'R0': 1.6, 'r': 0.18999999999999997},
#  {'R0': 1.6, 'r': 0.20999999999999996},
#  {'R0': 1.6, 'r': 0.22999999999999998},
#  {'R0': 1.6, 'r': 0.24999999999999997},
#  {'R0': 1.6, 'r': 0.26999999999999996},
#  {'R0': 1.6, 'r': 0.29},
#  {'R0': 1.6, 'r': 0.30999999999999994},
#  {'R0': 1.6, 'r': 0.32999999999999996},
#  {'R0': 1.6, 'r': 0.35},
#  {'R0': 1.6, 'r': 0.36999999999999994},
#  {'R0': 1.6, 'r': 0.38999999999999996},
#  {'R0': 1.6, 'r': 0.4099999999999999},
#  {'R0': 1.6, 'r': 0.42999999999999994},
#  {'R0': 1.6, 'r': 0.44999999999999996},
#  {'R0': 1.6, 'r': 0.4699999999999999},
#  {'R0': 1.6, 'r': 0.48999999999999994},
#  {'R0': 1.6, 'r': 0.5099999999999999},
#  {'R0': 1.6, 'r': 0.5299999999999999},
#  {'R0': 1.6, 'r': 0.5499999999999999},
#  {'R0': 1.6, 'r': 0.57},
#  {'R0': 1.6, 'r': 0.59},
#  {'R0': 1.6, 'r': 0.6099999999999999},
#  {'R0': 1.6, 'r': 0.6299999999999999},
#  {'R0': 1.6, 'r': 0.6499999999999999},
#  {'R0': 1.6, 'r': 0.6699999999999999},
#  {'R0': 1.6, 'r': 0.69},
#  {'R0': 1.6, 'r': 0.7099999999999999},
#  {'R0': 1.6, 'r': 0.7299999999999999},
#  {'R0': 1.6, 'r': 0.7499999999999999},
#  {'R0': 1.6, 'r': 0.7699999999999999},
#  {'R0': 1.6, 'r': 0.7899999999999999},
#  {'R0': 1.6, 'r': 0.8099999999999998},
#  {'R0': 1.6, 'r': 0.8299999999999998},
#  {'R0': 1.6, 'r': 0.8499999999999999},
#  {'R0': 1.6, 'r': 0.8699999999999999},
#  {'R0': 1.6, 'r': 0.8899999999999999},
#  {'R0': 1.6, 'r': 0.9099999999999999},
#  {'R0': 1.6, 'r': 0.9299999999999998},
#  {'R0': 1.6, 'r': 0.9499999999999998},
#  {'R0': 1.6, 'r': 0.9699999999999999},
#  {'R0': 1.6, 'r': 0.9899999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.01},
#  {'R0': 1.7000000000000002, 'r': 0.03},
#  {'R0': 1.7000000000000002, 'r': 0.049999999999999996},
#  {'R0': 1.7000000000000002, 'r': 0.06999999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.08999999999999998},
#  {'R0': 1.7000000000000002, 'r': 0.10999999999999997},
#  {'R0': 1.7000000000000002, 'r': 0.12999999999999998},
#  {'R0': 1.7000000000000002, 'r': 0.15},
#  {'R0': 1.7000000000000002, 'r': 0.16999999999999998},
#  {'R0': 1.7000000000000002, 'r': 0.18999999999999997},
#  {'R0': 1.7000000000000002, 'r': 0.20999999999999996},
#  {'R0': 1.7000000000000002, 'r': 0.22999999999999998},
#  {'R0': 1.7000000000000002, 'r': 0.24999999999999997},
#  {'R0': 1.7000000000000002, 'r': 0.26999999999999996},
#  {'R0': 1.7000000000000002, 'r': 0.29},
#  {'R0': 1.7000000000000002, 'r': 0.30999999999999994},
#  {'R0': 1.7000000000000002, 'r': 0.32999999999999996},
#  {'R0': 1.7000000000000002, 'r': 0.35},
#  {'R0': 1.7000000000000002, 'r': 0.36999999999999994},
#  {'R0': 1.7000000000000002, 'r': 0.38999999999999996},
#  {'R0': 1.7000000000000002, 'r': 0.4099999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.42999999999999994},
#  {'R0': 1.7000000000000002, 'r': 0.44999999999999996},
#  {'R0': 1.7000000000000002, 'r': 0.4699999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.48999999999999994},
#  {'R0': 1.7000000000000002, 'r': 0.5099999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.5299999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.5499999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.57},
#  {'R0': 1.7000000000000002, 'r': 0.59},
#  {'R0': 1.7000000000000002, 'r': 0.6099999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.6299999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.6499999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.6699999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.69},
#  {'R0': 1.7000000000000002, 'r': 0.7099999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.7299999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.7499999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.7699999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.7899999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.8099999999999998},
#  {'R0': 1.7000000000000002, 'r': 0.8299999999999998},
#  {'R0': 1.7000000000000002, 'r': 0.8499999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.8699999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.8899999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.9099999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.9299999999999998},
#  {'R0': 1.7000000000000002, 'r': 0.9499999999999998},
#  {'R0': 1.7000000000000002, 'r': 0.9699999999999999},
#  {'R0': 1.7000000000000002, 'r': 0.9899999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.01},
#  {'R0': 1.8000000000000003, 'r': 0.03},
#  {'R0': 1.8000000000000003, 'r': 0.049999999999999996},
#  {'R0': 1.8000000000000003, 'r': 0.06999999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.08999999999999998},
#  {'R0': 1.8000000000000003, 'r': 0.10999999999999997},
#  {'R0': 1.8000000000000003, 'r': 0.12999999999999998},
#  {'R0': 1.8000000000000003, 'r': 0.15},
#  {'R0': 1.8000000000000003, 'r': 0.16999999999999998},
#  {'R0': 1.8000000000000003, 'r': 0.18999999999999997},
#  {'R0': 1.8000000000000003, 'r': 0.20999999999999996},
#  {'R0': 1.8000000000000003, 'r': 0.22999999999999998},
#  {'R0': 1.8000000000000003, 'r': 0.24999999999999997},
#  {'R0': 1.8000000000000003, 'r': 0.26999999999999996},
#  {'R0': 1.8000000000000003, 'r': 0.29},
#  {'R0': 1.8000000000000003, 'r': 0.30999999999999994},
#  {'R0': 1.8000000000000003, 'r': 0.32999999999999996},
#  {'R0': 1.8000000000000003, 'r': 0.35},
#  {'R0': 1.8000000000000003, 'r': 0.36999999999999994},
#  {'R0': 1.8000000000000003, 'r': 0.38999999999999996},
#  {'R0': 1.8000000000000003, 'r': 0.4099999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.42999999999999994},
#  {'R0': 1.8000000000000003, 'r': 0.44999999999999996},
#  {'R0': 1.8000000000000003, 'r': 0.4699999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.48999999999999994},
#  {'R0': 1.8000000000000003, 'r': 0.5099999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.5299999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.5499999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.57},
#  {'R0': 1.8000000000000003, 'r': 0.59},
#  {'R0': 1.8000000000000003, 'r': 0.6099999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.6299999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.6499999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.6699999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.69},
#  {'R0': 1.8000000000000003, 'r': 0.7099999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.7299999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.7499999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.7699999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.7899999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.8099999999999998},
#  {'R0': 1.8000000000000003, 'r': 0.8299999999999998},
#  {'R0': 1.8000000000000003, 'r': 0.8499999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.8699999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.8899999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.9099999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.9299999999999998},
#  {'R0': 1.8000000000000003, 'r': 0.9499999999999998},
#  {'R0': 1.8000000000000003, 'r': 0.9699999999999999},
#  {'R0': 1.8000000000000003, 'r': 0.9899999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.01},
#  {'R0': 1.9000000000000004, 'r': 0.03},
#  {'R0': 1.9000000000000004, 'r': 0.049999999999999996},
#  {'R0': 1.9000000000000004, 'r': 0.06999999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.08999999999999998},
#  {'R0': 1.9000000000000004, 'r': 0.10999999999999997},
#  {'R0': 1.9000000000000004, 'r': 0.12999999999999998},
#  {'R0': 1.9000000000000004, 'r': 0.15},
#  {'R0': 1.9000000000000004, 'r': 0.16999999999999998},
#  {'R0': 1.9000000000000004, 'r': 0.18999999999999997},
#  {'R0': 1.9000000000000004, 'r': 0.20999999999999996},
#  {'R0': 1.9000000000000004, 'r': 0.22999999999999998},
#  {'R0': 1.9000000000000004, 'r': 0.24999999999999997},
#  {'R0': 1.9000000000000004, 'r': 0.26999999999999996},
#  {'R0': 1.9000000000000004, 'r': 0.29},
#  {'R0': 1.9000000000000004, 'r': 0.30999999999999994},
#  {'R0': 1.9000000000000004, 'r': 0.32999999999999996},
#  {'R0': 1.9000000000000004, 'r': 0.35},
#  {'R0': 1.9000000000000004, 'r': 0.36999999999999994},
#  {'R0': 1.9000000000000004, 'r': 0.38999999999999996},
#  {'R0': 1.9000000000000004, 'r': 0.4099999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.42999999999999994},
#  {'R0': 1.9000000000000004, 'r': 0.44999999999999996},
#  {'R0': 1.9000000000000004, 'r': 0.4699999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.48999999999999994},
#  {'R0': 1.9000000000000004, 'r': 0.5099999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.5299999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.5499999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.57},
#  {'R0': 1.9000000000000004, 'r': 0.59},
#  {'R0': 1.9000000000000004, 'r': 0.6099999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.6299999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.6499999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.6699999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.69},
#  {'R0': 1.9000000000000004, 'r': 0.7099999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.7299999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.7499999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.7699999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.7899999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.8099999999999998},
#  {'R0': 1.9000000000000004, 'r': 0.8299999999999998},
#  {'R0': 1.9000000000000004, 'r': 0.8499999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.8699999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.8899999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.9099999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.9299999999999998},
#  {'R0': 1.9000000000000004, 'r': 0.9499999999999998},
#  {'R0': 1.9000000000000004, 'r': 0.9699999999999999},
#  {'R0': 1.9000000000000004, 'r': 0.9899999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.01},
#  {'R0': 2.0000000000000004, 'r': 0.03},
#  {'R0': 2.0000000000000004, 'r': 0.049999999999999996},
#  {'R0': 2.0000000000000004, 'r': 0.06999999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.08999999999999998},
#  {'R0': 2.0000000000000004, 'r': 0.10999999999999997},
#  {'R0': 2.0000000000000004, 'r': 0.12999999999999998},
#  {'R0': 2.0000000000000004, 'r': 0.15},
#  {'R0': 2.0000000000000004, 'r': 0.16999999999999998},
#  {'R0': 2.0000000000000004, 'r': 0.18999999999999997},
#  {'R0': 2.0000000000000004, 'r': 0.20999999999999996},
#  {'R0': 2.0000000000000004, 'r': 0.22999999999999998},
#  {'R0': 2.0000000000000004, 'r': 0.24999999999999997},
#  {'R0': 2.0000000000000004, 'r': 0.26999999999999996},
#  {'R0': 2.0000000000000004, 'r': 0.29},
#  {'R0': 2.0000000000000004, 'r': 0.30999999999999994},
#  {'R0': 2.0000000000000004, 'r': 0.32999999999999996},
#  {'R0': 2.0000000000000004, 'r': 0.35},
#  {'R0': 2.0000000000000004, 'r': 0.36999999999999994},
#  {'R0': 2.0000000000000004, 'r': 0.38999999999999996},
#  {'R0': 2.0000000000000004, 'r': 0.4099999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.42999999999999994},
#  {'R0': 2.0000000000000004, 'r': 0.44999999999999996},
#  {'R0': 2.0000000000000004, 'r': 0.4699999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.48999999999999994},
#  {'R0': 2.0000000000000004, 'r': 0.5099999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.5299999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.5499999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.57},
#  {'R0': 2.0000000000000004, 'r': 0.59},
#  {'R0': 2.0000000000000004, 'r': 0.6099999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.6299999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.6499999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.6699999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.69},
#  {'R0': 2.0000000000000004, 'r': 0.7099999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.7299999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.7499999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.7699999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.7899999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.8099999999999998},
#  {'R0': 2.0000000000000004, 'r': 0.8299999999999998},
#  {'R0': 2.0000000000000004, 'r': 0.8499999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.8699999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.8899999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.9099999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.9299999999999998},
#  {'R0': 2.0000000000000004, 'r': 0.9499999999999998},
#  {'R0': 2.0000000000000004, 'r': 0.9699999999999999},
#  {'R0': 2.0000000000000004, 'r': 0.9899999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.01},
#  {'R0': 2.1000000000000005, 'r': 0.03},
#  {'R0': 2.1000000000000005, 'r': 0.049999999999999996},
#  {'R0': 2.1000000000000005, 'r': 0.06999999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.08999999999999998},
#  {'R0': 2.1000000000000005, 'r': 0.10999999999999997},
#  {'R0': 2.1000000000000005, 'r': 0.12999999999999998},
#  {'R0': 2.1000000000000005, 'r': 0.15},
#  {'R0': 2.1000000000000005, 'r': 0.16999999999999998},
#  {'R0': 2.1000000000000005, 'r': 0.18999999999999997},
#  {'R0': 2.1000000000000005, 'r': 0.20999999999999996},
#  {'R0': 2.1000000000000005, 'r': 0.22999999999999998},
#  {'R0': 2.1000000000000005, 'r': 0.24999999999999997},
#  {'R0': 2.1000000000000005, 'r': 0.26999999999999996},
#  {'R0': 2.1000000000000005, 'r': 0.29},
#  {'R0': 2.1000000000000005, 'r': 0.30999999999999994},
#  {'R0': 2.1000000000000005, 'r': 0.32999999999999996},
#  {'R0': 2.1000000000000005, 'r': 0.35},
#  {'R0': 2.1000000000000005, 'r': 0.36999999999999994},
#  {'R0': 2.1000000000000005, 'r': 0.38999999999999996},
#  {'R0': 2.1000000000000005, 'r': 0.4099999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.42999999999999994},
#  {'R0': 2.1000000000000005, 'r': 0.44999999999999996},
#  {'R0': 2.1000000000000005, 'r': 0.4699999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.48999999999999994},
#  {'R0': 2.1000000000000005, 'r': 0.5099999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.5299999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.5499999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.57},
#  {'R0': 2.1000000000000005, 'r': 0.59},
#  {'R0': 2.1000000000000005, 'r': 0.6099999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.6299999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.6499999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.6699999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.69},
#  {'R0': 2.1000000000000005, 'r': 0.7099999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.7299999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.7499999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.7699999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.7899999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.8099999999999998},
#  {'R0': 2.1000000000000005, 'r': 0.8299999999999998},
#  {'R0': 2.1000000000000005, 'r': 0.8499999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.8699999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.8899999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.9099999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.9299999999999998},
#  {'R0': 2.1000000000000005, 'r': 0.9499999999999998},
#  {'R0': 2.1000000000000005, 'r': 0.9699999999999999},
#  {'R0': 2.1000000000000005, 'r': 0.9899999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.01},
#  {'R0': 2.2000000000000006, 'r': 0.03},
#  {'R0': 2.2000000000000006, 'r': 0.049999999999999996},
#  {'R0': 2.2000000000000006, 'r': 0.06999999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.08999999999999998},
#  {'R0': 2.2000000000000006, 'r': 0.10999999999999997},
#  {'R0': 2.2000000000000006, 'r': 0.12999999999999998},
#  {'R0': 2.2000000000000006, 'r': 0.15},
#  {'R0': 2.2000000000000006, 'r': 0.16999999999999998},
#  {'R0': 2.2000000000000006, 'r': 0.18999999999999997},
#  {'R0': 2.2000000000000006, 'r': 0.20999999999999996},
#  {'R0': 2.2000000000000006, 'r': 0.22999999999999998},
#  {'R0': 2.2000000000000006, 'r': 0.24999999999999997},
#  {'R0': 2.2000000000000006, 'r': 0.26999999999999996},
#  {'R0': 2.2000000000000006, 'r': 0.29},
#  {'R0': 2.2000000000000006, 'r': 0.30999999999999994},
#  {'R0': 2.2000000000000006, 'r': 0.32999999999999996},
#  {'R0': 2.2000000000000006, 'r': 0.35},
#  {'R0': 2.2000000000000006, 'r': 0.36999999999999994},
#  {'R0': 2.2000000000000006, 'r': 0.38999999999999996},
#  {'R0': 2.2000000000000006, 'r': 0.4099999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.42999999999999994},
#  {'R0': 2.2000000000000006, 'r': 0.44999999999999996},
#  {'R0': 2.2000000000000006, 'r': 0.4699999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.48999999999999994},
#  {'R0': 2.2000000000000006, 'r': 0.5099999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.5299999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.5499999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.57},
#  {'R0': 2.2000000000000006, 'r': 0.59},
#  {'R0': 2.2000000000000006, 'r': 0.6099999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.6299999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.6499999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.6699999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.69},
#  {'R0': 2.2000000000000006, 'r': 0.7099999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.7299999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.7499999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.7699999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.7899999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.8099999999999998},
#  {'R0': 2.2000000000000006, 'r': 0.8299999999999998},
#  {'R0': 2.2000000000000006, 'r': 0.8499999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.8699999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.8899999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.9099999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.9299999999999998},
#  {'R0': 2.2000000000000006, 'r': 0.9499999999999998},
#  {'R0': 2.2000000000000006, 'r': 0.9699999999999999},
#  {'R0': 2.2000000000000006, 'r': 0.9899999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.01},
#  {'R0': 2.3000000000000007, 'r': 0.03},
#  {'R0': 2.3000000000000007, 'r': 0.049999999999999996},
#  {'R0': 2.3000000000000007, 'r': 0.06999999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.08999999999999998},
#  {'R0': 2.3000000000000007, 'r': 0.10999999999999997},
#  {'R0': 2.3000000000000007, 'r': 0.12999999999999998},
#  {'R0': 2.3000000000000007, 'r': 0.15},
#  {'R0': 2.3000000000000007, 'r': 0.16999999999999998},
#  {'R0': 2.3000000000000007, 'r': 0.18999999999999997},
#  {'R0': 2.3000000000000007, 'r': 0.20999999999999996},
#  {'R0': 2.3000000000000007, 'r': 0.22999999999999998},
#  {'R0': 2.3000000000000007, 'r': 0.24999999999999997},
#  {'R0': 2.3000000000000007, 'r': 0.26999999999999996},
#  {'R0': 2.3000000000000007, 'r': 0.29},
#  {'R0': 2.3000000000000007, 'r': 0.30999999999999994},
#  {'R0': 2.3000000000000007, 'r': 0.32999999999999996},
#  {'R0': 2.3000000000000007, 'r': 0.35},
#  {'R0': 2.3000000000000007, 'r': 0.36999999999999994},
#  {'R0': 2.3000000000000007, 'r': 0.38999999999999996},
#  {'R0': 2.3000000000000007, 'r': 0.4099999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.42999999999999994},
#  {'R0': 2.3000000000000007, 'r': 0.44999999999999996},
#  {'R0': 2.3000000000000007, 'r': 0.4699999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.48999999999999994},
#  {'R0': 2.3000000000000007, 'r': 0.5099999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.5299999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.5499999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.57},
#  {'R0': 2.3000000000000007, 'r': 0.59},
#  {'R0': 2.3000000000000007, 'r': 0.6099999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.6299999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.6499999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.6699999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.69},
#  {'R0': 2.3000000000000007, 'r': 0.7099999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.7299999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.7499999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.7699999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.7899999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.8099999999999998},
#  {'R0': 2.3000000000000007, 'r': 0.8299999999999998},
#  {'R0': 2.3000000000000007, 'r': 0.8499999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.8699999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.8899999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.9099999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.9299999999999998},
#  {'R0': 2.3000000000000007, 'r': 0.9499999999999998},
#  {'R0': 2.3000000000000007, 'r': 0.9699999999999999},
#  {'R0': 2.3000000000000007, 'r': 0.9899999999999999},
#  {'R0': 2.400000000000001, 'r': 0.01},
#  {'R0': 2.400000000000001, 'r': 0.03},
#  {'R0': 2.400000000000001, 'r': 0.049999999999999996},
#  {'R0': 2.400000000000001, 'r': 0.06999999999999999},
#  {'R0': 2.400000000000001, 'r': 0.08999999999999998},
#  {'R0': 2.400000000000001, 'r': 0.10999999999999997},
#  {'R0': 2.400000000000001, 'r': 0.12999999999999998},
#  {'R0': 2.400000000000001, 'r': 0.15},
#  {'R0': 2.400000000000001, 'r': 0.16999999999999998},
#  {'R0': 2.400000000000001, 'r': 0.18999999999999997},
#  {'R0': 2.400000000000001, 'r': 0.20999999999999996},
#  {'R0': 2.400000000000001, 'r': 0.22999999999999998},
#  {'R0': 2.400000000000001, 'r': 0.24999999999999997},
#  {'R0': 2.400000000000001, 'r': 0.26999999999999996},
#  {'R0': 2.400000000000001, 'r': 0.29},
#  {'R0': 2.400000000000001, 'r': 0.30999999999999994},
#  {'R0': 2.400000000000001, 'r': 0.32999999999999996},
#  {'R0': 2.400000000000001, 'r': 0.35},
#  {'R0': 2.400000000000001, 'r': 0.36999999999999994},
#  {'R0': 2.400000000000001, 'r': 0.38999999999999996},
#  {'R0': 2.400000000000001, 'r': 0.4099999999999999},
#  {'R0': 2.400000000000001, 'r': 0.42999999999999994},
#  {'R0': 2.400000000000001, 'r': 0.44999999999999996},
#  {'R0': 2.400000000000001, 'r': 0.4699999999999999},
#  {'R0': 2.400000000000001, 'r': 0.48999999999999994},
#  {'R0': 2.400000000000001, 'r': 0.5099999999999999},
#  {'R0': 2.400000000000001, 'r': 0.5299999999999999},
#  {'R0': 2.400000000000001, 'r': 0.5499999999999999},
#  {'R0': 2.400000000000001, 'r': 0.57},
#  {'R0': 2.400000000000001, 'r': 0.59},
#  {'R0': 2.400000000000001, 'r': 0.6099999999999999},
#  {'R0': 2.400000000000001, 'r': 0.6299999999999999},
#  {'R0': 2.400000000000001, 'r': 0.6499999999999999},
#  {'R0': 2.400000000000001, 'r': 0.6699999999999999},
#  {'R0': 2.400000000000001, 'r': 0.69},
#  {'R0': 2.400000000000001, 'r': 0.7099999999999999},
#  {'R0': 2.400000000000001, 'r': 0.7299999999999999},
#  {'R0': 2.400000000000001, 'r': 0.7499999999999999},
#  {'R0': 2.400000000000001, 'r': 0.7699999999999999},
#  {'R0': 2.400000000000001, 'r': 0.7899999999999999},
#  {'R0': 2.400000000000001, 'r': 0.8099999999999998},
#  {'R0': 2.400000000000001, 'r': 0.8299999999999998},
#  {'R0': 2.400000000000001, 'r': 0.8499999999999999},
#  {'R0': 2.400000000000001, 'r': 0.8699999999999999},
#  {'R0': 2.400000000000001, 'r': 0.8899999999999999},
#  {'R0': 2.400000000000001, 'r': 0.9099999999999999},
#  {'R0': 2.400000000000001, 'r': 0.9299999999999998},
#  {'R0': 2.400000000000001, 'r': 0.9499999999999998},
#  {'R0': 2.400000000000001, 'r': 0.9699999999999999},
#  {'R0': 2.400000000000001, 'r': 0.9899999999999999},
#  {'R0': 2.500000000000001, 'r': 0.01},
#  {'R0': 2.500000000000001, 'r': 0.03},
#  {'R0': 2.500000000000001, 'r': 0.049999999999999996},
#  {'R0': 2.500000000000001, 'r': 0.06999999999999999},
#  {'R0': 2.500000000000001, 'r': 0.08999999999999998},
#  {'R0': 2.500000000000001, 'r': 0.10999999999999997},
#  {'R0': 2.500000000000001, 'r': 0.12999999999999998},
#  {'R0': 2.500000000000001, 'r': 0.15},
#  {'R0': 2.500000000000001, 'r': 0.16999999999999998},
#  {'R0': 2.500000000000001, 'r': 0.18999999999999997},
#  {'R0': 2.500000000000001, 'r': 0.20999999999999996},
#  {'R0': 2.500000000000001, 'r': 0.22999999999999998},
#  {'R0': 2.500000000000001, 'r': 0.24999999999999997},
#  {'R0': 2.500000000000001, 'r': 0.26999999999999996},
#  {'R0': 2.500000000000001, 'r': 0.29},
#  {'R0': 2.500000000000001, 'r': 0.30999999999999994},
#  {'R0': 2.500000000000001, 'r': 0.32999999999999996},
#  {'R0': 2.500000000000001, 'r': 0.35},
#  {'R0': 2.500000000000001, 'r': 0.36999999999999994},
#  {'R0': 2.500000000000001, 'r': 0.38999999999999996},
#  {'R0': 2.500000000000001, 'r': 0.4099999999999999},
#  {'R0': 2.500000000000001, 'r': 0.42999999999999994},
#  {'R0': 2.500000000000001, 'r': 0.44999999999999996},
#  {'R0': 2.500000000000001, 'r': 0.4699999999999999},
#  {'R0': 2.500000000000001, 'r': 0.48999999999999994},
#  {'R0': 2.500000000000001, 'r': 0.5099999999999999},
#  {'R0': 2.500000000000001, 'r': 0.5299999999999999},
#  {'R0': 2.500000000000001, 'r': 0.5499999999999999},
#  {'R0': 2.500000000000001, 'r': 0.57},
#  {'R0': 2.500000000000001, 'r': 0.59},
#  {'R0': 2.500000000000001, 'r': 0.6099999999999999},
#  {'R0': 2.500000000000001, 'r': 0.6299999999999999},
#  {'R0': 2.500000000000001, 'r': 0.6499999999999999},
#  {'R0': 2.500000000000001, 'r': 0.6699999999999999},
#  {'R0': 2.500000000000001, 'r': 0.69},
#  {'R0': 2.500000000000001, 'r': 0.7099999999999999},
#  {'R0': 2.500000000000001, 'r': 0.7299999999999999},
#  {'R0': 2.500000000000001, 'r': 0.7499999999999999},
#  {'R0': 2.500000000000001, 'r': 0.7699999999999999},
#  {'R0': 2.500000000000001, 'r': 0.7899999999999999},
#  {'R0': 2.500000000000001, 'r': 0.8099999999999998},
#  {'R0': 2.500000000000001, 'r': 0.8299999999999998},
#  {'R0': 2.500000000000001, 'r': 0.8499999999999999},
#  {'R0': 2.500000000000001, 'r': 0.8699999999999999},
#  {'R0': 2.500000000000001, 'r': 0.8899999999999999},
#  {'R0': 2.500000000000001, 'r': 0.9099999999999999},
#  {'R0': 2.500000000000001, 'r': 0.9299999999999998},
#  {'R0': 2.500000000000001, 'r': 0.9499999999999998},
#  {'R0': 2.500000000000001, 'r': 0.9699999999999999},
#  {'R0': 2.500000000000001, 'r': 0.9899999999999999},
#  {'R0': 2.600000000000001, 'r': 0.01},
#  {'R0': 2.600000000000001, 'r': 0.03},
#  {'R0': 2.600000000000001, 'r': 0.049999999999999996},
#  {'R0': 2.600000000000001, 'r': 0.06999999999999999},
#  {'R0': 2.600000000000001, 'r': 0.08999999999999998},
#  {'R0': 2.600000000000001, 'r': 0.10999999999999997},
#  {'R0': 2.600000000000001, 'r': 0.12999999999999998},
#  {'R0': 2.600000000000001, 'r': 0.15},
#  {'R0': 2.600000000000001, 'r': 0.16999999999999998},
#  {'R0': 2.600000000000001, 'r': 0.18999999999999997},
#  {'R0': 2.600000000000001, 'r': 0.20999999999999996},
#  {'R0': 2.600000000000001, 'r': 0.22999999999999998},
#  {'R0': 2.600000000000001, 'r': 0.24999999999999997},
#  {'R0': 2.600000000000001, 'r': 0.26999999999999996},
#  {'R0': 2.600000000000001, 'r': 0.29},
#  {'R0': 2.600000000000001, 'r': 0.30999999999999994},
#  {'R0': 2.600000000000001, 'r': 0.32999999999999996},
#  {'R0': 2.600000000000001, 'r': 0.35},
#  {'R0': 2.600000000000001, 'r': 0.36999999999999994},
#  {'R0': 2.600000000000001, 'r': 0.38999999999999996},
#  {'R0': 2.600000000000001, 'r': 0.4099999999999999},
#  {'R0': 2.600000000000001, 'r': 0.42999999999999994},
#  {'R0': 2.600000000000001, 'r': 0.44999999999999996},
#  {'R0': 2.600000000000001, 'r': 0.4699999999999999},
#  {'R0': 2.600000000000001, 'r': 0.48999999999999994},
#  {'R0': 2.600000000000001, 'r': 0.5099999999999999},
#  {'R0': 2.600000000000001, 'r': 0.5299999999999999},
#  {'R0': 2.600000000000001, 'r': 0.5499999999999999},
#  {'R0': 2.600000000000001, 'r': 0.57},
#  {'R0': 2.600000000000001, 'r': 0.59},
#  {'R0': 2.600000000000001, 'r': 0.6099999999999999},
#  {'R0': 2.600000000000001, 'r': 0.6299999999999999},
#  {'R0': 2.600000000000001, 'r': 0.6499999999999999},
#  {'R0': 2.600000000000001, 'r': 0.6699999999999999},
#  {'R0': 2.600000000000001, 'r': 0.69},
#  {'R0': 2.600000000000001, 'r': 0.7099999999999999},
#  {'R0': 2.600000000000001, 'r': 0.7299999999999999},
#  {'R0': 2.600000000000001, 'r': 0.7499999999999999},
#  {'R0': 2.600000000000001, 'r': 0.7699999999999999},
#  {'R0': 2.600000000000001, 'r': 0.7899999999999999},
#  {'R0': 2.600000000000001, 'r': 0.8099999999999998},
#  {'R0': 2.600000000000001, 'r': 0.8299999999999998},
#  {'R0': 2.600000000000001, 'r': 0.8499999999999999},
#  {'R0': 2.600000000000001, 'r': 0.8699999999999999},
#  {'R0': 2.600000000000001, 'r': 0.8899999999999999},
#  {'R0': 2.600000000000001, 'r': 0.9099999999999999},
#  {'R0': 2.600000000000001, 'r': 0.9299999999999998},
#  {'R0': 2.600000000000001, 'r': 0.9499999999999998},
#  {'R0': 2.600000000000001, 'r': 0.9699999999999999},
#  {'R0': 2.600000000000001, 'r': 0.9899999999999999},
#  {'R0': 2.700000000000001, 'r': 0.01},
#  {'R0': 2.700000000000001, 'r': 0.03},
#  {'R0': 2.700000000000001, 'r': 0.049999999999999996},
#  {'R0': 2.700000000000001, 'r': 0.06999999999999999},
#  {'R0': 2.700000000000001, 'r': 0.08999999999999998},
#  {'R0': 2.700000000000001, 'r': 0.10999999999999997},
#  {'R0': 2.700000000000001, 'r': 0.12999999999999998},
#  {'R0': 2.700000000000001, 'r': 0.15},
#  {'R0': 2.700000000000001, 'r': 0.16999999999999998},
#  {'R0': 2.700000000000001, 'r': 0.18999999999999997},
#  {'R0': 2.700000000000001, 'r': 0.20999999999999996},
#  {'R0': 2.700000000000001, 'r': 0.22999999999999998},
#  {'R0': 2.700000000000001, 'r': 0.24999999999999997},
#  {'R0': 2.700000000000001, 'r': 0.26999999999999996},
#  {'R0': 2.700000000000001, 'r': 0.29},
#  {'R0': 2.700000000000001, 'r': 0.30999999999999994},
#  {'R0': 2.700000000000001, 'r': 0.32999999999999996},
#  {'R0': 2.700000000000001, 'r': 0.35},
#  {'R0': 2.700000000000001, 'r': 0.36999999999999994},
#  {'R0': 2.700000000000001, 'r': 0.38999999999999996},
#  {'R0': 2.700000000000001, 'r': 0.4099999999999999},
#  {'R0': 2.700000000000001, 'r': 0.42999999999999994},
#  {'R0': 2.700000000000001, 'r': 0.44999999999999996},
#  {'R0': 2.700000000000001, 'r': 0.4699999999999999},
#  {'R0': 2.700000000000001, 'r': 0.48999999999999994},
#  {'R0': 2.700000000000001, 'r': 0.5099999999999999},
#  {'R0': 2.700000000000001, 'r': 0.5299999999999999},
#  {'R0': 2.700000000000001, 'r': 0.5499999999999999},
#  {'R0': 2.700000000000001, 'r': 0.57},
#  {'R0': 2.700000000000001, 'r': 0.59},
#  {'R0': 2.700000000000001, 'r': 0.6099999999999999},
#  {'R0': 2.700000000000001, 'r': 0.6299999999999999},
#  {'R0': 2.700000000000001, 'r': 0.6499999999999999},
#  {'R0': 2.700000000000001, 'r': 0.6699999999999999},
#  {'R0': 2.700000000000001, 'r': 0.69},
#  {'R0': 2.700000000000001, 'r': 0.7099999999999999},
#  {'R0': 2.700000000000001, 'r': 0.7299999999999999},
#  {'R0': 2.700000000000001, 'r': 0.7499999999999999},
#  {'R0': 2.700000000000001, 'r': 0.7699999999999999},
#  {'R0': 2.700000000000001, 'r': 0.7899999999999999},
#  {'R0': 2.700000000000001, 'r': 0.8099999999999998},
#  {'R0': 2.700000000000001, 'r': 0.8299999999999998},
#  {'R0': 2.700000000000001, 'r': 0.8499999999999999},
#  {'R0': 2.700000000000001, 'r': 0.8699999999999999},
#  {'R0': 2.700000000000001, 'r': 0.8899999999999999},
#  {'R0': 2.700000000000001, 'r': 0.9099999999999999},
#  {'R0': 2.700000000000001, 'r': 0.9299999999999998},
#  {'R0': 2.700000000000001, 'r': 0.9499999999999998},
#  {'R0': 2.700000000000001, 'r': 0.9699999999999999},
#  {'R0': 2.700000000000001, 'r': 0.9899999999999999},
#  {'R0': 2.800000000000001, 'r': 0.01},
#  {'R0': 2.800000000000001, 'r': 0.03},
#  {'R0': 2.800000000000001, 'r': 0.049999999999999996},
#  {'R0': 2.800000000000001, 'r': 0.06999999999999999},
#  {'R0': 2.800000000000001, 'r': 0.08999999999999998},
#  {'R0': 2.800000000000001, 'r': 0.10999999999999997},
#  {'R0': 2.800000000000001, 'r': 0.12999999999999998},
#  {'R0': 2.800000000000001, 'r': 0.15},
#  {'R0': 2.800000000000001, 'r': 0.16999999999999998},
#  {'R0': 2.800000000000001, 'r': 0.18999999999999997},
#  {'R0': 2.800000000000001, 'r': 0.20999999999999996},
#  {'R0': 2.800000000000001, 'r': 0.22999999999999998},
#  {'R0': 2.800000000000001, 'r': 0.24999999999999997},
#  {'R0': 2.800000000000001, 'r': 0.26999999999999996},
#  {'R0': 2.800000000000001, 'r': 0.29},
#  {'R0': 2.800000000000001, 'r': 0.30999999999999994},
#  {'R0': 2.800000000000001, 'r': 0.32999999999999996},
#  {'R0': 2.800000000000001, 'r': 0.35},
#  {'R0': 2.800000000000001, 'r': 0.36999999999999994},
#  {'R0': 2.800000000000001, 'r': 0.38999999999999996},
#  {'R0': 2.800000000000001, 'r': 0.4099999999999999},
#  {'R0': 2.800000000000001, 'r': 0.42999999999999994},
#  {'R0': 2.800000000000001, 'r': 0.44999999999999996},
#  {'R0': 2.800000000000001, 'r': 0.4699999999999999},
#  {'R0': 2.800000000000001, 'r': 0.48999999999999994},
#  {'R0': 2.800000000000001, 'r': 0.5099999999999999},
#  {'R0': 2.800000000000001, 'r': 0.5299999999999999},
#  {'R0': 2.800000000000001, 'r': 0.5499999999999999},
#  {'R0': 2.800000000000001, 'r': 0.57},
#  {'R0': 2.800000000000001, 'r': 0.59},
#  {'R0': 2.800000000000001, 'r': 0.6099999999999999},
#  {'R0': 2.800000000000001, 'r': 0.6299999999999999},
#  {'R0': 2.800000000000001, 'r': 0.6499999999999999},
#  {'R0': 2.800000000000001, 'r': 0.6699999999999999},
#  {'R0': 2.800000000000001, 'r': 0.69},
#  {'R0': 2.800000000000001, 'r': 0.7099999999999999},
#  {'R0': 2.800000000000001, 'r': 0.7299999999999999},
#  {'R0': 2.800000000000001, 'r': 0.7499999999999999},
#  {'R0': 2.800000000000001, 'r': 0.7699999999999999},
#  {'R0': 2.800000000000001, 'r': 0.7899999999999999},
#  {'R0': 2.800000000000001, 'r': 0.8099999999999998},
#  {'R0': 2.800000000000001, 'r': 0.8299999999999998},
#  {'R0': 2.800000000000001, 'r': 0.8499999999999999},
#  {'R0': 2.800000000000001, 'r': 0.8699999999999999},
#  {'R0': 2.800000000000001, 'r': 0.8899999999999999},
#  {'R0': 2.800000000000001, 'r': 0.9099999999999999},
#  {'R0': 2.800000000000001, 'r': 0.9299999999999998},
#  {'R0': 2.800000000000001, 'r': 0.9499999999999998},
#  {'R0': 2.800000000000001, 'r': 0.9699999999999999},
#  {'R0': 2.800000000000001, 'r': 0.9899999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.01},
#  {'R0': 2.9000000000000012, 'r': 0.03},
#  {'R0': 2.9000000000000012, 'r': 0.049999999999999996},
#  {'R0': 2.9000000000000012, 'r': 0.06999999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.08999999999999998},
#  {'R0': 2.9000000000000012, 'r': 0.10999999999999997},
#  {'R0': 2.9000000000000012, 'r': 0.12999999999999998},
#  {'R0': 2.9000000000000012, 'r': 0.15},
#  {'R0': 2.9000000000000012, 'r': 0.16999999999999998},
#  {'R0': 2.9000000000000012, 'r': 0.18999999999999997},
#  {'R0': 2.9000000000000012, 'r': 0.20999999999999996},
#  {'R0': 2.9000000000000012, 'r': 0.22999999999999998},
#  {'R0': 2.9000000000000012, 'r': 0.24999999999999997},
#  {'R0': 2.9000000000000012, 'r': 0.26999999999999996},
#  {'R0': 2.9000000000000012, 'r': 0.29},
#  {'R0': 2.9000000000000012, 'r': 0.30999999999999994},
#  {'R0': 2.9000000000000012, 'r': 0.32999999999999996},
#  {'R0': 2.9000000000000012, 'r': 0.35},
#  {'R0': 2.9000000000000012, 'r': 0.36999999999999994},
#  {'R0': 2.9000000000000012, 'r': 0.38999999999999996},
#  {'R0': 2.9000000000000012, 'r': 0.4099999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.42999999999999994},
#  {'R0': 2.9000000000000012, 'r': 0.44999999999999996},
#  {'R0': 2.9000000000000012, 'r': 0.4699999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.48999999999999994},
#  {'R0': 2.9000000000000012, 'r': 0.5099999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.5299999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.5499999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.57},
#  {'R0': 2.9000000000000012, 'r': 0.59},
#  {'R0': 2.9000000000000012, 'r': 0.6099999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.6299999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.6499999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.6699999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.69},
#  {'R0': 2.9000000000000012, 'r': 0.7099999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.7299999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.7499999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.7699999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.7899999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.8099999999999998},
#  {'R0': 2.9000000000000012, 'r': 0.8299999999999998},
#  {'R0': 2.9000000000000012, 'r': 0.8499999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.8699999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.8899999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.9099999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.9299999999999998},
#  {'R0': 2.9000000000000012, 'r': 0.9499999999999998},
#  {'R0': 2.9000000000000012, 'r': 0.9699999999999999},
#  {'R0': 2.9000000000000012, 'r': 0.9899999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.01},
#  {'R0': 3.0000000000000013, 'r': 0.03},
#  {'R0': 3.0000000000000013, 'r': 0.049999999999999996},
#  {'R0': 3.0000000000000013, 'r': 0.06999999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.08999999999999998},
#  {'R0': 3.0000000000000013, 'r': 0.10999999999999997},
#  {'R0': 3.0000000000000013, 'r': 0.12999999999999998},
#  {'R0': 3.0000000000000013, 'r': 0.15},
#  {'R0': 3.0000000000000013, 'r': 0.16999999999999998},
#  {'R0': 3.0000000000000013, 'r': 0.18999999999999997},
#  {'R0': 3.0000000000000013, 'r': 0.20999999999999996},
#  {'R0': 3.0000000000000013, 'r': 0.22999999999999998},
#  {'R0': 3.0000000000000013, 'r': 0.24999999999999997},
#  {'R0': 3.0000000000000013, 'r': 0.26999999999999996},
#  {'R0': 3.0000000000000013, 'r': 0.29},
#  {'R0': 3.0000000000000013, 'r': 0.30999999999999994},
#  {'R0': 3.0000000000000013, 'r': 0.32999999999999996},
#  {'R0': 3.0000000000000013, 'r': 0.35},
#  {'R0': 3.0000000000000013, 'r': 0.36999999999999994},
#  {'R0': 3.0000000000000013, 'r': 0.38999999999999996},
#  {'R0': 3.0000000000000013, 'r': 0.4099999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.42999999999999994},
#  {'R0': 3.0000000000000013, 'r': 0.44999999999999996},
#  {'R0': 3.0000000000000013, 'r': 0.4699999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.48999999999999994},
#  {'R0': 3.0000000000000013, 'r': 0.5099999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.5299999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.5499999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.57},
#  {'R0': 3.0000000000000013, 'r': 0.59},
#  {'R0': 3.0000000000000013, 'r': 0.6099999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.6299999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.6499999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.6699999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.69},
#  {'R0': 3.0000000000000013, 'r': 0.7099999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.7299999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.7499999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.7699999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.7899999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.8099999999999998},
#  {'R0': 3.0000000000000013, 'r': 0.8299999999999998},
#  {'R0': 3.0000000000000013, 'r': 0.8499999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.8699999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.8899999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.9099999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.9299999999999998},
#  {'R0': 3.0000000000000013, 'r': 0.9499999999999998},
#  {'R0': 3.0000000000000013, 'r': 0.9699999999999999},
#  {'R0': 3.0000000000000013, 'r': 0.9899999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.01},
#  {'R0': 3.1000000000000014, 'r': 0.03},
#  {'R0': 3.1000000000000014, 'r': 0.049999999999999996},
#  {'R0': 3.1000000000000014, 'r': 0.06999999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.08999999999999998},
#  {'R0': 3.1000000000000014, 'r': 0.10999999999999997},
#  {'R0': 3.1000000000000014, 'r': 0.12999999999999998},
#  {'R0': 3.1000000000000014, 'r': 0.15},
#  {'R0': 3.1000000000000014, 'r': 0.16999999999999998},
#  {'R0': 3.1000000000000014, 'r': 0.18999999999999997},
#  {'R0': 3.1000000000000014, 'r': 0.20999999999999996},
#  {'R0': 3.1000000000000014, 'r': 0.22999999999999998},
#  {'R0': 3.1000000000000014, 'r': 0.24999999999999997},
#  {'R0': 3.1000000000000014, 'r': 0.26999999999999996},
#  {'R0': 3.1000000000000014, 'r': 0.29},
#  {'R0': 3.1000000000000014, 'r': 0.30999999999999994},
#  {'R0': 3.1000000000000014, 'r': 0.32999999999999996},
#  {'R0': 3.1000000000000014, 'r': 0.35},
#  {'R0': 3.1000000000000014, 'r': 0.36999999999999994},
#  {'R0': 3.1000000000000014, 'r': 0.38999999999999996},
#  {'R0': 3.1000000000000014, 'r': 0.4099999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.42999999999999994},
#  {'R0': 3.1000000000000014, 'r': 0.44999999999999996},
#  {'R0': 3.1000000000000014, 'r': 0.4699999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.48999999999999994},
#  {'R0': 3.1000000000000014, 'r': 0.5099999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.5299999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.5499999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.57},
#  {'R0': 3.1000000000000014, 'r': 0.59},
#  {'R0': 3.1000000000000014, 'r': 0.6099999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.6299999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.6499999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.6699999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.69},
#  {'R0': 3.1000000000000014, 'r': 0.7099999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.7299999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.7499999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.7699999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.7899999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.8099999999999998},
#  {'R0': 3.1000000000000014, 'r': 0.8299999999999998},
#  {'R0': 3.1000000000000014, 'r': 0.8499999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.8699999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.8899999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.9099999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.9299999999999998},
#  {'R0': 3.1000000000000014, 'r': 0.9499999999999998},
#  {'R0': 3.1000000000000014, 'r': 0.9699999999999999},
#  {'R0': 3.1000000000000014, 'r': 0.9899999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.01},
#  {'R0': 3.2000000000000015, 'r': 0.03},
#  {'R0': 3.2000000000000015, 'r': 0.049999999999999996},
#  {'R0': 3.2000000000000015, 'r': 0.06999999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.08999999999999998},
#  {'R0': 3.2000000000000015, 'r': 0.10999999999999997},
#  {'R0': 3.2000000000000015, 'r': 0.12999999999999998},
#  {'R0': 3.2000000000000015, 'r': 0.15},
#  {'R0': 3.2000000000000015, 'r': 0.16999999999999998},
#  {'R0': 3.2000000000000015, 'r': 0.18999999999999997},
#  {'R0': 3.2000000000000015, 'r': 0.20999999999999996},
#  {'R0': 3.2000000000000015, 'r': 0.22999999999999998},
#  {'R0': 3.2000000000000015, 'r': 0.24999999999999997},
#  {'R0': 3.2000000000000015, 'r': 0.26999999999999996},
#  {'R0': 3.2000000000000015, 'r': 0.29},
#  {'R0': 3.2000000000000015, 'r': 0.30999999999999994},
#  {'R0': 3.2000000000000015, 'r': 0.32999999999999996},
#  {'R0': 3.2000000000000015, 'r': 0.35},
#  {'R0': 3.2000000000000015, 'r': 0.36999999999999994},
#  {'R0': 3.2000000000000015, 'r': 0.38999999999999996},
#  {'R0': 3.2000000000000015, 'r': 0.4099999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.42999999999999994},
#  {'R0': 3.2000000000000015, 'r': 0.44999999999999996},
#  {'R0': 3.2000000000000015, 'r': 0.4699999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.48999999999999994},
#  {'R0': 3.2000000000000015, 'r': 0.5099999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.5299999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.5499999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.57},
#  {'R0': 3.2000000000000015, 'r': 0.59},
#  {'R0': 3.2000000000000015, 'r': 0.6099999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.6299999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.6499999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.6699999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.69},
#  {'R0': 3.2000000000000015, 'r': 0.7099999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.7299999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.7499999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.7699999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.7899999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.8099999999999998},
#  {'R0': 3.2000000000000015, 'r': 0.8299999999999998},
#  {'R0': 3.2000000000000015, 'r': 0.8499999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.8699999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.8899999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.9099999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.9299999999999998},
#  {'R0': 3.2000000000000015, 'r': 0.9499999999999998},
#  {'R0': 3.2000000000000015, 'r': 0.9699999999999999},
#  {'R0': 3.2000000000000015, 'r': 0.9899999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.01},
#  {'R0': 3.3000000000000016, 'r': 0.03},
#  {'R0': 3.3000000000000016, 'r': 0.049999999999999996},
#  {'R0': 3.3000000000000016, 'r': 0.06999999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.08999999999999998},
#  {'R0': 3.3000000000000016, 'r': 0.10999999999999997},
#  {'R0': 3.3000000000000016, 'r': 0.12999999999999998},
#  {'R0': 3.3000000000000016, 'r': 0.15},
#  {'R0': 3.3000000000000016, 'r': 0.16999999999999998},
#  {'R0': 3.3000000000000016, 'r': 0.18999999999999997},
#  {'R0': 3.3000000000000016, 'r': 0.20999999999999996},
#  {'R0': 3.3000000000000016, 'r': 0.22999999999999998},
#  {'R0': 3.3000000000000016, 'r': 0.24999999999999997},
#  {'R0': 3.3000000000000016, 'r': 0.26999999999999996},
#  {'R0': 3.3000000000000016, 'r': 0.29},
#  {'R0': 3.3000000000000016, 'r': 0.30999999999999994},
#  {'R0': 3.3000000000000016, 'r': 0.32999999999999996},
#  {'R0': 3.3000000000000016, 'r': 0.35},
#  {'R0': 3.3000000000000016, 'r': 0.36999999999999994},
#  {'R0': 3.3000000000000016, 'r': 0.38999999999999996},
#  {'R0': 3.3000000000000016, 'r': 0.4099999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.42999999999999994},
#  {'R0': 3.3000000000000016, 'r': 0.44999999999999996},
#  {'R0': 3.3000000000000016, 'r': 0.4699999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.48999999999999994},
#  {'R0': 3.3000000000000016, 'r': 0.5099999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.5299999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.5499999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.57},
#  {'R0': 3.3000000000000016, 'r': 0.59},
#  {'R0': 3.3000000000000016, 'r': 0.6099999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.6299999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.6499999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.6699999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.69},
#  {'R0': 3.3000000000000016, 'r': 0.7099999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.7299999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.7499999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.7699999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.7899999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.8099999999999998},
#  {'R0': 3.3000000000000016, 'r': 0.8299999999999998},
#  {'R0': 3.3000000000000016, 'r': 0.8499999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.8699999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.8899999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.9099999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.9299999999999998},
#  {'R0': 3.3000000000000016, 'r': 0.9499999999999998},
#  {'R0': 3.3000000000000016, 'r': 0.9699999999999999},
#  {'R0': 3.3000000000000016, 'r': 0.9899999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.01},
#  {'R0': 3.4000000000000017, 'r': 0.03},
#  {'R0': 3.4000000000000017, 'r': 0.049999999999999996},
#  {'R0': 3.4000000000000017, 'r': 0.06999999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.08999999999999998},
#  {'R0': 3.4000000000000017, 'r': 0.10999999999999997},
#  {'R0': 3.4000000000000017, 'r': 0.12999999999999998},
#  {'R0': 3.4000000000000017, 'r': 0.15},
#  {'R0': 3.4000000000000017, 'r': 0.16999999999999998},
#  {'R0': 3.4000000000000017, 'r': 0.18999999999999997},
#  {'R0': 3.4000000000000017, 'r': 0.20999999999999996},
#  {'R0': 3.4000000000000017, 'r': 0.22999999999999998},
#  {'R0': 3.4000000000000017, 'r': 0.24999999999999997},
#  {'R0': 3.4000000000000017, 'r': 0.26999999999999996},
#  {'R0': 3.4000000000000017, 'r': 0.29},
#  {'R0': 3.4000000000000017, 'r': 0.30999999999999994},
#  {'R0': 3.4000000000000017, 'r': 0.32999999999999996},
#  {'R0': 3.4000000000000017, 'r': 0.35},
#  {'R0': 3.4000000000000017, 'r': 0.36999999999999994},
#  {'R0': 3.4000000000000017, 'r': 0.38999999999999996},
#  {'R0': 3.4000000000000017, 'r': 0.4099999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.42999999999999994},
#  {'R0': 3.4000000000000017, 'r': 0.44999999999999996},
#  {'R0': 3.4000000000000017, 'r': 0.4699999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.48999999999999994},
#  {'R0': 3.4000000000000017, 'r': 0.5099999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.5299999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.5499999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.57},
#  {'R0': 3.4000000000000017, 'r': 0.59},
#  {'R0': 3.4000000000000017, 'r': 0.6099999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.6299999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.6499999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.6699999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.69},
#  {'R0': 3.4000000000000017, 'r': 0.7099999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.7299999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.7499999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.7699999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.7899999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.8099999999999998},
#  {'R0': 3.4000000000000017, 'r': 0.8299999999999998},
#  {'R0': 3.4000000000000017, 'r': 0.8499999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.8699999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.8899999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.9099999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.9299999999999998},
#  {'R0': 3.4000000000000017, 'r': 0.9499999999999998},
#  {'R0': 3.4000000000000017, 'r': 0.9699999999999999},
#  {'R0': 3.4000000000000017, 'r': 0.9899999999999999}]

# %%
### count the simulation times 
s_times = {}
for i in para_dict[636:1000]:
    R0 = i['R0']
    r = i['r']
    count = 0
    for s in range(500):
        file_name = file_dir + "NewInf_R0-{}_r-{}_{}.npy.gz" .format(np.round(R0,2),np.round(r,2),s)
        check_file = os.path.isfile(file_name)
        if check_file == True:
            count = count +1
    s_times['R0',R0,'r',r] = count

# %%
pop = np.loadtxt('pop_new.csv')
### analyse the data

# %%
# Numcounty_mean =  np.zeros((50,20))
# Numcounty_std =  np.zeros((50,20))
save_dir = '../../../../../../Volumes/My Passport/branching/results/'
for i in range(50)[2:]:
    for j in range(20):
        R0 = R0s[j]
        r = rs[i]
        count = s_times['R0',R0,'r',r] 
        temp = np.zeros((count,3142,60))
        if count == 500:
            for s in range(count):
                file_name = file_dir + "NewInf_R0-{}_r-{}_{}.npy.gz" .format(np.round(R0,2),np.round(r,2),s)
                f = gzip.GzipFile(file_name, "r")
                xx = np.load(f)
                temp[i] = xx[:,:60]
            
            f = gzip.GzipFile(save_dir+"NewInf_R0-{}_r-{}.npy.gz" .format(np.round(R0,2),np.round(r,2)), "w")
            np.save(file=f, arr=temp)
            f.close()

            E_daily_per_pop = temp/pop[None,:,None]*100000
            num_county = np.sum(E_daily_per_pop>10,axis=1)

            mean_county = np.mean(num_county,axis=0)[40]
            Numcounty_mean[i,j] = mean_county

            std_county = np.std(num_county,axis=0)[40]
            Numcounty_std[i,j] = std_county

# %%
temp = np.load(f)
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# /var/folders/vx/g_l159t12yb63094n730n4pm0000gn/T/ipykernel_2045/1597645582.py in <module>
# ----> 1 temp = np.load(f)
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     422         _ZIP_SUFFIX = b'PK\x05\x06' # empty zip files start with this
#     423         N = len(format.MAGIC_PREFIX)
# --> 424         magic = fid.read(N)
#     425         # If the file size is less than N, we need to make sure not
#     426         # to seek past the beginning of the file
#
# /opt/anaconda3/lib/python3.9/gzip.py in read(self, size)
#     298             import errno
#     299             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 300         return self._buffer.read(size)
#     301
#     302     def read1(self, size=-1):
#
# /opt/anaconda3/lib/python3.9/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /opt/anaconda3/lib/python3.9/gzip.py in read(self, size)
#     476                 # Check the CRC and file size, and set the flag so we read
#     477                 # a new member
# --> 478                 self._read_eof()
#     479                 self._new_member = True
#     480                 self._decompressor = self._decomp_factory(
#
# /opt/anaconda3/lib/python3.9/gzip.py in _read_eof(self)
#     522         crc32, isize = struct.unpack("<II", self._read_exact(8))
#     523         if crc32 != self._crc:
# --> 524             raise BadGzipFile("CRC check failed %s != %s" % (hex(crc32),
#     525                                                              hex(self._crc)))
#     526         elif isize != (self._stream_size & 0xffffffff):
#
# BadGzipFile: CRC check failed 0x55555555 != 0x32b4fb4c

# %%
Numcounty_mean60 =  np.zeros((50,20))
Numcounty_std60 =  np.zeros((50,20))
save_dir = '../../../../../../Volumes/My Passport/branching/results/'
for i in range(50):
    for j in range(20):
        R0 = R0s[j]
        r = rs[i]
        count = s_times['R0',R0,'r',r] 
        temp = np.zeros((count,3142,60))
        if count == 500:
            gzip.GzipFile
            f = gzip.GzipFile(save_dir+"NewInf_R0-{}_r-{}.npy.gz" .format(np.round(R0,2),np.round(r,2)), "r")
            temp = np.load(f)

            E_daily_per_pop = temp/pop[None,:,None]*100000
            num_county = np.sum(E_daily_per_pop>10,axis=1)

            mean_county = np.mean(num_county,axis=0)[59]
            Numcounty_mean60[i,j] = mean_county

            std_county = np.std(num_county,axis=0)[59]
            Numcounty_std60[i,j] = std_county
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# /var/folders/vx/g_l159t12yb63094n730n4pm0000gn/T/ipykernel_2045/3810345687.py in <module>
#      10         if count == 500:
#      11             f = gzip.GzipFile(save_dir+"NewInf_R0-{}_r-{}.npy.gz" .format(np.round(R0,2),np.round(r,2)), "r")
# ---> 12             temp = np.load(f)
#      13
#      14             E_daily_per_pop = temp/pop[None,:,None]*100000
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438                 return format.open_memmap(file, mode=mmap_mode)
#     439             else:
# --> 440                 return format.read_array(fid, allow_pickle=allow_pickle,
#     441                                          pickle_kwargs=pickle_kwargs)
#     442         else:
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     773                     read_count = min(max_read_count, count - i)
#     774                     read_size = int(read_count * dtype.itemsize)
# --> 775                     data = _read_bytes(fp, read_size, "array data")
#     776                     array[i:i+read_count] = numpy.frombuffer(data, dtype=dtype,
#     777                                                              count=read_count)
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/lib/format.py in _read_bytes(fp, size, error_template)
#     902         # done about that.  note that regular files can't be non-blocking
#     903         try:
# --> 904             r = fp.read(size - len(data))
#     905             data += r
#     906             if len(r) == 0 or len(data) == size:
#
# /opt/anaconda3/lib/python3.9/gzip.py in read(self, size)
#     298             import errno
#     299             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 300         return self._buffer.read(size)
#     301
#     302     def read1(self, size=-1):
#
# /opt/anaconda3/lib/python3.9/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /opt/anaconda3/lib/python3.9/gzip.py in read(self, size)
#     476                 # Check the CRC and file size, and set the flag so we read
#     477                 # a new member
# --> 478                 self._read_eof()
#     479                 self._new_member = True
#     480                 self._decompressor = self._decomp_factory(
#
# /opt/anaconda3/lib/python3.9/gzip.py in _read_eof(self)
#     522         crc32, isize = struct.unpack("<II", self._read_exact(8))
#     523         if crc32 != self._crc:
# --> 524             raise BadGzipFile("CRC check failed %s != %s" % (hex(crc32),
#     525                                                              hex(self._crc)))
#     526         elif isize != (self._stream_size & 0xffffffff):
#
# BadGzipFile: CRC check failed 0xacc42cae != 0x32b4fb4c

# %%
y = rs[:50]
x = R0s[:6]

X, Y = np.meshgrid(x, y)

Z = Numcounty_mean[:,:6]


fig1, ax2 = plt.subplots(figsize=(5, 4), dpi=450)
contour = ax2.contourf(X, Y, Z, 10, cmap=plt.cm.viridis)

# Add colorbar
cbh = plt.colorbar(contour, orientation='vertical', pad=0.05)
# cbh.ax.set_yticklabels([10, 50, 100])
cbh.ax.tick_params(labelsize=12)

# Turn off grid and set shading
# plt.grid(False)
# contour.set_edgecolor('face') # remove contour lines

# Set title and axis labels
plt.title('the number of counties per 100k population >10 at t=40', fontsize=16)
plt.xlabel('R0', fontsize=12)
plt.ylabel('r', fontsize=12)

# Set axis limits and font size
plt.xlim([x[0], x[-1]])
plt.ylim([y[0], y[-1]])
plt.tick_params(axis='both', which='major', labelsize=14)

plt.show()

# %%
X.shape
# Out:
# (20, 20)

# %%
f = gzip.GzipFile(file_name, "r")

# %%
plt.figure(dpi=450,figsize=(6,4))
plt.plot(mean_county,label='r=0.15',color='purple')
plt.fill_between(range(60),mean_county-std_county,mean_county +std_county,color='purple',alpha=0.1)

# %%
# create a binary pickle file 
f = open("s_times_final.pkl","wb")

# write the python object (dict) to pickle file
pickle.dump(s_times,f)

# close file
f.close()

# %%
f1 = open('s_times.pkl', 'rb')
x1 = pickle.load(f1)

# %%
s_redo = {}
for i in para_dict[:1000]:
    R0 = i['R0']
    r = i['r']
    count = s_times['R0',R0,'r',r] 
    if count != 500:
        s_redo['R0',R0,'r',r] = 500-count
