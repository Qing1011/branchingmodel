# %%
import torch
from torch.nn import Linear
from torch_geometric.nn import GCNConv, global_mean_pool, TopKPooling
from torch_geometric.data import Data,DataLoader
# from torch_geometric.loader import DataLoader
import torch.nn.functional as F
from torch_geometric.utils.convert import from_scipy_sparse_matrix
from torch_geometric.utils.convert import from_networkx
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat, savemat
import pandas as pd
import scipy.special as SS
import scipy.stats as SSA
import copy
import math
from sklearn.model_selection import ParameterGrid
import os
import numpy.linalg as LA
import gzip

from scipy import sparse

# load pickle module
import pickle
import networkx as nx
import torch.nn as nn

# %%
x = np.array(range(30))
y = np.array(range(3142))

X, Y = np.meshgrid(x, y)

g_i[g_i == 0] = 0.00001
Z = np.log(g_i[:,30:])
# Z = g_i[:,30:]

fig1, ax2 = plt.subplots(figsize=(5, 4), dpi=450)
contour = ax2.contourf(X, Y, Z, 10, cmap=plt.cm.viridis,vmin=0) #vmax=36

# contour = ax2.imshow(Z,cmap=plt.cm.coolwarm)

# Add colorbar
cbh = plt.colorbar(contour, orientation='vertical', pad=0.05)
# cbh.ax.set_yticklabels([10, 50, 100])

# %%
R0 = 2.5
rs = np.array([20, 10, 2.0, 1.0, 0.5, 0.2, 0.1, 0.05, 0.025])

# %%
WN = np.loadtxt('../W_avg.csv') ### numpy arrary

# %%
# Number of nodes (rows of the matrix)
num_nodes = 3142

# Number of features per node (columns of the matrix)
num_features = 60

# Number of classes
num_classes = 6

# Create a random matrix

# %%
# Create a graph from mobility matrix
GM = nx.from_numpy_array(WN)
edges = np.array(GM.edges()).transpose()
edge_index = torch.tensor(edges,dtype = torch.int64)

# %%
def load_gzipped_numpy(filename):
    try:
        with gzip.open(filename, 'rb') as f:
            return np.load(f, allow_pickle=True)
    except FileNotFoundError:
        return [0]

# %%
export_dir = '/Users/qingyao/Documents/branching_data/simulation/python_cutoff/'
#### data preparation
dataset = []
r_class = {}
for r_idx in range(9):
    r = rs[r_idx]
    sub_export_dir = export_dir+'branching_R0-{}_r-{}/'.format(np.round(R0,2),np.round(r,3))
    print(r)
    # Create a list to hold our Data objects
    for g_idx in range(300):
        export_names = sub_export_dir+'NewInf_R0-{}_r-{}_{}.npy.gz'.format(np.round(R0,2),np.round(r,3),(g_idx+1))
        g_i = load_gzipped_numpy(export_names)
        g_i[g_i == 0] = 0.0000001 ### use the log to make the pattern more obvious
        Z = np.log(g_i[:,10:]) ### previous are almost 0
        matrix = torch.from_numpy(g_i[:,10:])
        y = torch.tensor([r_idx], dtype=torch.long)
        # Create a Data object for each graph
        data = Data(x=matrix, edge_index=edge_index, y=y)
#         data = Data(x=ma_normalized, edge_index=edge_index, y=y)
        data.x = data.x.float()
        data.y = data.y.long()
        # Add the Data object to our list
        dataset.append(data)
# Out:
# 20.0
# 10.0
# 2.0
# 1.0
# 0.5
# 0.2
# 0.1
# 0.05
# 0.025

# %%
from torch.utils.data import random_split
train_data, test_data = random_split(dataset, [1800, 900])

# %%
class GCN(torch.nn.Module): ### the simpliest model that GNN and it is classical, used as baseline fo most o
    def __init__(self, num_node_features, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(num_node_features, 128) ### aggreagted, aggreaction function properly, 
        ## this change the mean of the neighbour 
        ## example we can do contact all the values 
        # if we change this function we can get higher order interaction for free
        self.conv2 = GCNConv(128, 128)
        self.conv3 = GCNConv(128, 64)
        
        self.classifier = Linear(64, num_classes)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First Graph Convolution
        x = self.conv1(x, edge_index)
        x = F.relu(x) ### 
#         x = F.dropout(x, p=0.5, training=self.training)

        # Second Graph Convolution
        x = self.conv2(x, edge_index)
        x = F.relu(x)
#         x = F.dropout(x, p=0.5, training=self.training) ### sometimes i do not need the dropout
        ## avoid the local minimal too high here the loss function can be smoothy
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        
        # Global Pooling (mean)
        x = global_mean_pool(x, batch)

        # Classification
        x = self.classifier(x)
        #F.log_softmax(x, dim=1)

        return x

# Now we can create a DataLoader
myloader = DataLoader(train_data, batch_size=64, shuffle=True)

# Create a model and an optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GCN(num_node_features=50, num_classes=9).to(device) ### only look at the last 30 
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

def train():
    model.train()
    loss_all = 0
    correct = 0
    total = 0
    for data in myloader:
        data = data.to(device)
        optimizer.zero_grad() # 清空梯度
        output = model(data) # 前向计算
        label = data.y.to(device)
        # Cross entropy loss
        loss = F.cross_entropy(output, label)
#         loss = F.kl_div(output, label)
        loss.backward() # 反向传播
        loss_all += data.num_graphs * loss.item()
        optimizer.step()  # 更新参数
        _, predicted = torch.max(output, 1)  # Change "outputs" to "output"
        total += label.size(0)  # Change "labels" to "label"
        correct += (predicted == label).sum().item()  # Change "labels" to "label"
    accuracy = 100 * correct / total
    return loss_all / len(myloader.dataset), accuracy


loss_ep = []
ac_ep = []
for epoch in range(100):
    loss,ac = train()
    loss_ep.append(loss)
    ac_ep.append(ac)
    print('Epoch: {:03d}, Loss: {:.5f}, ac: {:.5f}'.format(epoch, loss, ac))
# Out:
# Epoch: 000, Loss: 3.09960, ac: 19.11111
# Epoch: 001, Loss: 1.75059, ac: 30.33333
# Epoch: 002, Loss: 1.66160, ac: 34.72222
# Epoch: 003, Loss: 1.56226, ac: 36.83333
# Epoch: 004, Loss: 1.51171, ac: 40.38889
# Epoch: 005, Loss: 1.51354, ac: 39.00000
# Epoch: 006, Loss: 1.55639, ac: 37.50000
# Epoch: 007, Loss: 1.48198, ac: 39.33333
# Epoch: 008, Loss: 1.49755, ac: 37.88889
# Epoch: 009, Loss: 1.43938, ac: 39.66667
# Epoch: 010, Loss: 1.49194, ac: 38.72222
# Epoch: 011, Loss: 1.45207, ac: 39.44444
# Epoch: 012, Loss: 1.41716, ac: 40.83333
# Epoch: 013, Loss: 1.44275, ac: 41.22222
# Epoch: 014, Loss: 1.45120, ac: 39.55556
# Epoch: 015, Loss: 1.51207, ac: 37.05556
# Epoch: 016, Loss: 1.42043, ac: 40.27778
# Epoch: 017, Loss: 1.37048, ac: 42.66667
# Epoch: 018, Loss: 1.47113, ac: 38.16667
# Epoch: 019, Loss: 1.53872, ac: 37.11111
# Epoch: 020, Loss: 1.48326, ac: 37.38889
# Epoch: 021, Loss: 1.44980, ac: 39.72222
# Epoch: 022, Loss: 1.38403, ac: 41.33333
# Epoch: 023, Loss: 1.39896, ac: 41.27778
# Epoch: 024, Loss: 1.39596, ac: 41.55556
# Epoch: 025, Loss: 1.40052, ac: 41.38889
# Epoch: 026, Loss: 1.34511, ac: 43.27778
# Epoch: 027, Loss: 1.40023, ac: 40.27778
# Epoch: 028, Loss: 1.43647, ac: 39.38889
# Epoch: 029, Loss: 1.44663, ac: 40.88889

# %%
plt.plot(loss_ep)
# plt.plot(ac_ep,color='green')
plt.xlabel('Epoch',size=12)
# plt.ylabel('Accuracy')
plt.ylabel('MSE Loss',size=12)
# Out:
# Text(0, 0.5, 'MSE Loss')

# %%
len(dataset)
# Out:
# 2700

# %%
# Example unseen graph data (make sure it's similar to your training data in structure)
unseen_data = [dataset[1], dataset[310], dataset[660], dataset[1000]]  # Replace with your actual graph data

# Convert to DataLoader
unseen_loader = DataLoader(test_data, batch_size=32)  # Adjust batch size as needed

# Function for prediction
def predict(loader):
    model.eval()  # Set model to evaluation mode
    predictions = []

    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            output = model(data)
            predicted_class = torch.argmax(output, dim=1)
            predictions.extend(predicted_class.cpu().numpy().tolist())

    return predictions

# Get predictions
predicted_classes = predict(unseen_loader)
# print(predicted_classes)
# Out:
# /Users/qingyao/anaconda3/envs/gnn/lib/python3.11/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
correct = 0
total = 0
y_test = []
# ac = []
for i in range(len(test_data)):
    data_i = test_data[i]
    predicted =  predicted_classes[i]
    label = data_i.y.to(device)
    total += label.size(0)  # Change "labels" to "label"
    correct += (predicted == label).sum().item()
    y_test.append(label)# Change "labels" to "label"
accuracy = 100 * correct / total

# %%
y_test
# Out:
# [tensor([4]),
#  tensor([2]),
#  tensor([0]),
#  tensor([0]),
#  tensor([6]),
#  tensor([7]),
#  tensor([2]),
#  tensor([8]),
#  tensor([6]),
#  tensor([8]),
#  tensor([8]),
#  tensor([1]),
#  tensor([8]),
#  tensor([4]),
#  tensor([0]),
#  tensor([0]),
#  tensor([5]),
#  tensor([6]),
#  tensor([5]),
#  tensor([2]),
#  tensor([7]),
#  tensor([1]),
#  tensor([0]),
#  tensor([1]),
#  tensor([1]),
#  tensor([0]),
#  tensor([8]),
#  tensor([3]),
#  tensor([4]),
#  tensor([7]),
#  tensor([4]),
#  tensor([8]),
#  tensor([0]),
#  tensor([0]),
#  tensor([5]),
#  tensor([1]),
#  tensor([8]),
#  tensor([7]),
#  tensor([4]),
#  tensor([8]),
#  tensor([8]),
#  tensor([4]),
#  tensor([0]),
#  tensor([0]),
#  tensor([4]),
#  tensor([1]),
#  tensor([7]),
#  tensor([3]),
#  tensor([3]),
#  tensor([0]),
#  tensor([0]),
#  tensor([1]),
#  tensor([6]),
#  tensor([3]),
#  tensor([6]),
#  tensor([4]),
#  tensor([1]),
#  tensor([4]),
#  tensor([1]),
#  tensor([6]),
#  tensor([6]),
#  tensor([8]),
#  tensor([5]),
#  tensor([5]),
#  tensor([2]),
#  tensor([8]),
#  tensor([7]),
#  tensor([1]),
#  tensor([3]),
#  tensor([1]),
#  tensor([5]),
#  tensor([1]),
#  tensor([1]),
#  tensor([1]),
#  tensor([6]),
#  tensor([7]),
#  tensor([7]),
#  tensor([3]),
#  tensor([5]),
#  tensor([4]),
#  tensor([6]),
#  tensor([5]),
#  tensor([7]),
#  tensor([4]),
#  tensor([5]),
#  tensor([6]),
#  tensor([2]),
#  tensor([7]),
#  tensor([2]),
#  tensor([1]),
#  tensor([8]),
#  tensor([3]),
#  tensor([1]),
#  tensor([0]),
#  tensor([8]),
#  tensor([2]),
#  tensor([6]),
#  tensor([5]),
#  tensor([4]),
#  tensor([4]),
#  tensor([7]),
#  tensor([5]),
#  tensor([7]),
#  tensor([3]),
#  tensor([7]),
#  tensor([1]),
#  tensor([7]),
#  tensor([7]),
#  tensor([0]),
#  tensor([8]),
#  tensor([1]),
#  tensor([5]),
#  tensor([1]),
#  tensor([5]),
#  tensor([1]),
#  tensor([6]),
#  tensor([2]),
#  tensor([1]),
#  tensor([3]),
#  tensor([1]),
#  tensor([0]),
#  tensor([7]),
#  tensor([4]),
#  tensor([3]),
#  tensor([3]),
#  tensor([2]),
#  tensor([1]),
#  tensor([4]),
#  tensor([2]),
#  tensor([3]),
#  tensor([6]),
#  tensor([8]),
#  tensor([8]),
#  tensor([6]),
#  tensor([7]),
#  tensor([8]),
#  tensor([0]),
#  tensor([5]),
#  tensor([0]),
#  tensor([4]),
#  tensor([3]),
#  tensor([8]),
#  tensor([2]),
#  tensor([6]),
#  tensor([7]),
#  tensor([0]),
#  tensor([7]),
#  tensor([4]),
#  tensor([4]),
#  tensor([8]),
#  tensor([0]),
#  tensor([0]),
#  tensor([3]),
#  tensor([8]),
#  tensor([6]),
#  tensor([1]),
#  tensor([1]),
#  tensor([2]),
#  tensor([2]),
#  tensor([6]),
#  tensor([0]),
#  tensor([3]),
#  tensor([3]),
#  tensor([8]),
#  tensor([8]),
#  tensor([6]),
#  tensor([2]),
#  tensor([7]),
#  tensor([7]),
#  tensor([1]),
#  tensor([4]),
#  tensor([1]),
#  tensor([6]),
#  tensor([5]),
#  tensor([4]),
#  tensor([0]),
#  tensor([2]),
#  tensor([6]),
#  tensor([1]),
#  tensor([2]),
#  tensor([8]),
#  tensor([0]),
#  tensor([6]),
#  tensor([2]),
#  tensor([6]),
#  tensor([2]),
#  tensor([7]),
#  tensor([1]),
#  tensor([4]),
#  tensor([6]),
#  tensor([3]),
#  tensor([6]),
#  tensor([0]),
#  tensor([6]),
#  tensor([4]),
#  tensor([1]),
#  tensor([7]),
#  tensor([1]),
#  tensor([4]),
#  tensor([0]),
#  tensor([8]),
#  tensor([5]),
#  tensor([4]),
#  tensor([7]),
#  tensor([5]),
#  tensor([2]),
#  tensor([6]),
#  tensor([3]),
#  tensor([0]),
#  tensor([0]),
#  tensor([0]),
#  tensor([2]),
#  tensor([3]),
#  tensor([1]),
#  tensor([2]),
#  tensor([4]),
#  tensor([2]),
#  tensor([8]),
#  tensor([7]),
#  tensor([6]),
#  tensor([0]),
#  tensor([7]),
#  tensor([1]),
#  tensor([0]),
#  tensor([5]),
#  tensor([6]),
#  tensor([2]),
#  tensor([4]),
#  tensor([5]),
#  tensor([6]),
#  tensor([1]),
#  tensor([7]),
#  tensor([0]),
#  tensor([4]),
#  tensor([0]),
#  tensor([0]),
#  tensor([4]),
#  tensor([7]),
#  tensor([7]),
#  tensor([0]),
#  tensor([2]),
#  tensor([6]),
#  tensor([3]),
#  tensor([0]),
#  tensor([4]),
#  tensor([7]),
#  tensor([3]),
#  tensor([3]),
#  tensor([0]),
#  tensor([1]),
#  tensor([2]),
#  tensor([5]),
#  tensor([5]),
#  tensor([0]),
#  tensor([3]),
#  tensor([6]),
#  tensor([1]),
#  tensor([3]),
#  tensor([2]),
#  tensor([4]),
#  tensor([0]),
#  tensor([4]),
#  tensor([8]),
#  tensor([1]),
#  tensor([3]),
#  tensor([6]),
#  tensor([7]),
#  tensor([7]),
#  tensor([7]),
#  tensor([2]),
#  tensor([1]),
#  tensor([4]),
#  tensor([3]),
#  tensor([7]),
#  tensor([6]),
#  tensor([5]),
#  tensor([0]),
#  tensor([2]),
#  tensor([6]),
#  tensor([7]),
#  tensor([7]),
#  tensor([7]),
#  tensor([1]),
#  tensor([3]),
#  tensor([6]),
#  tensor([7]),
#  tensor([6]),
#  tensor([8]),
#  tensor([4]),
#  tensor([5]),
#  tensor([7]),
#  tensor([6]),
#  tensor([5]),
#  tensor([7]),
#  tensor([8]),
#  tensor([6]),
#  tensor([5]),
#  tensor([4]),
#  tensor([4]),
#  tensor([3]),
#  tensor([5]),
#  tensor([6]),
#  tensor([0]),
#  tensor([1]),
#  tensor([8]),
#  tensor([4]),
#  tensor([4]),
#  tensor([3]),
#  tensor([4]),
#  tensor([2]),
#  tensor([0]),
#  tensor([6]),
#  tensor([5]),
#  tensor([3]),
#  tensor([1]),
#  tensor([0]),
#  tensor([3]),
#  tensor([8]),
#  tensor([2]),
#  tensor([6]),
#  tensor([8]),
#  tensor([7]),
#  tensor([4]),
#  tensor([4]),
#  tensor([2]),
#  tensor([3]),
#  tensor([8]),
#  tensor([5]),
#  tensor([0]),
#  tensor([2]),
#  tensor([7]),
#  tensor([5]),
#  tensor([0]),
#  tensor([1]),
#  tensor([3]),
#  tensor([7]),
#  tensor([1]),
#  tensor([6]),
#  tensor([1]),
#  tensor([3]),
#  tensor([6]),
#  tensor([8]),
#  tensor([7]),
#  tensor([0]),
#  tensor([1]),
#  tensor([5]),
#  tensor([3]),
#  tensor([5]),
#  tensor([0]),
#  tensor([7]),
#  tensor([1]),
#  tensor([4]),
#  tensor([0]),
#  tensor([4]),
#  tensor([2]),
#  tensor([0]),
#  tensor([5]),
#  tensor([3]),
#  tensor([6]),
#  tensor([8]),
#  tensor([3]),
#  tensor([3]),
#  tensor([1]),
#  tensor([1]),
#  tensor([3]),
#  tensor([7]),
#  tensor([5]),
#  tensor([0]),
#  tensor([4]),
#  tensor([3]),
#  tensor([7]),
#  tensor([6]),
#  tensor([0]),
#  tensor([5]),
#  tensor([2]),
#  tensor([6]),
#  tensor([8]),
#  tensor([7]),
#  tensor([1]),
#  tensor([0]),
#  tensor([2]),
#  tensor([2]),
#  tensor([5]),
#  tensor([2]),
#  tensor([1]),
#  tensor([5]),
#  tensor([8]),
#  tensor([8]),
#  tensor([8]),
#  tensor([6]),
#  tensor([7]),
#  tensor([3]),
#  tensor([6]),
#  tensor([4]),
#  tensor([5]),
#  tensor([6]),
#  tensor([6]),
#  tensor([3]),
#  tensor([3]),
#  tensor([6]),
#  tensor([5]),
#  tensor([0]),
#  tensor([7]),
#  tensor([7]),
#  tensor([8]),
#  tensor([1]),
#  tensor([3]),
#  tensor([3]),
#  tensor([2]),
#  tensor([8]),
#  tensor([2]),
#  tensor([3]),
#  tensor([1]),
#  tensor([6]),
#  tensor([7]),
#  tensor([7]),
#  tensor([0]),
#  tensor([5]),
#  tensor([3]),
#  tensor([2]),
#  tensor([5]),
#  tensor([5]),
#  tensor([3]),
#  tensor([8]),
#  tensor([5]),
#  tensor([3]),
#  tensor([6]),
#  tensor([7]),
#  tensor([0]),
#  tensor([4]),
#  tensor([4]),
#  tensor([3]),
#  tensor([5]),
#  tensor([0]),
#  tensor([5]),
#  tensor([8]),
#  tensor([5]),
#  tensor([2]),
#  tensor([6]),
#  tensor([6]),
#  tensor([6]),
#  tensor([6]),
#  tensor([8]),
#  tensor([8]),
#  tensor([7]),
#  tensor([6]),
#  tensor([1]),
#  tensor([1]),
#  tensor([1]),
#  tensor([2]),
#  tensor([4]),
#  tensor([4]),
#  tensor([2]),
#  tensor([7]),
#  tensor([5]),
#  tensor([4]),
#  tensor([1]),
#  tensor([2]),
#  tensor([5]),
#  tensor([2]),
#  tensor([3]),
#  tensor([7]),
#  tensor([7]),
#  tensor([2]),
#  tensor([0]),
#  tensor([6]),
#  tensor([8]),
#  tensor([4]),
#  tensor([1]),
#  tensor([1]),
#  tensor([1]),
#  tensor([5]),
#  tensor([7]),
#  tensor([5]),
#  tensor([4]),
#  tensor([3]),
#  tensor([6]),
#  tensor([2]),
#  tensor([1]),
#  tensor([1]),
#  tensor([2]),
#  tensor([1]),
#  tensor([7]),
#  tensor([4]),
#  tensor([6]),
#  tensor([1]),
#  tensor([6]),
#  tensor([3]),
#  tensor([8]),
#  tensor([1]),
#  tensor([1]),
#  tensor([0]),
#  tensor([5]),
#  tensor([2]),
#  tensor([3]),
#  tensor([0]),
#  tensor([4]),
#  tensor([5]),
#  tensor([2]),
#  tensor([7]),
#  tensor([4]),
#  tensor([7]),
#  tensor([7]),
#  tensor([5]),
#  tensor([2]),
#  tensor([0]),
#  tensor([5]),
#  tensor([2]),
#  tensor([2]),
#  tensor([2]),
#  tensor([1]),
#  tensor([6]),
#  tensor([4]),
#  tensor([4]),
#  tensor([3]),
#  tensor([5]),
#  tensor([8]),
#  tensor([5]),
#  tensor([5]),
#  tensor([8]),
#  tensor([0]),
#  tensor([0]),
#  tensor([0]),
#  tensor([2]),
#  tensor([4]),
#  tensor([7]),
#  tensor([5]),
#  tensor([3]),
#  tensor([5]),
#  tensor([1]),
#  tensor([4]),
#  tensor([7]),
#  tensor([5]),
#  tensor([2]),
#  tensor([6]),
#  tensor([0]),
#  tensor([3]),
#  tensor([2]),
#  tensor([8]),
#  tensor([7]),
#  tensor([1]),
#  tensor([4]),
#  tensor([8]),
#  tensor([5]),
#  tensor([7]),
#  tensor([2]),
#  tensor([7]),
#  tensor([4]),
#  tensor([1]),
#  tensor([0]),
#  tensor([6]),
#  tensor([0]),
#  tensor([3]),
#  tensor([8]),
#  tensor([2]),
#  tensor([2]),
#  tensor([2]),
#  tensor([8]),
#  tensor([5]),
#  tensor([6]),
#  tensor([8]),
#  tensor([8]),
#  tensor([6]),
#  tensor([6]),
#  tensor([0]),
#  tensor([8]),
#  tensor([5]),
#  tensor([4]),
#  tensor([7]),
#  tensor([7]),
#  tensor([2]),
#  tensor([4]),
#  tensor([3]),
#  tensor([3]),
#  tensor([1]),
#  tensor([8]),
#  tensor([8]),
#  tensor([8]),
#  tensor([6]),
#  tensor([2]),
#  tensor([4]),
#  tensor([4]),
#  tensor([3]),
#  tensor([6]),
#  tensor([4]),
#  tensor([6]),
#  tensor([8]),
#  tensor([3]),
#  tensor([6]),
#  tensor([1]),
#  tensor([4]),
#  tensor([1]),
#  tensor([8]),
#  tensor([3]),
#  tensor([2]),
#  tensor([0]),
#  tensor([8]),
#  tensor([5]),
#  tensor([7]),
#  tensor([0]),
#  tensor([1]),
#  tensor([0]),
#  tensor([6]),
#  tensor([3]),
#  tensor([4]),
#  tensor([6]),
#  tensor([5]),
#  tensor([7]),
#  tensor([6]),
#  tensor([7]),
#  tensor([1]),
#  tensor([8]),
#  tensor([5]),
#  tensor([4]),
#  tensor([7]),
#  tensor([3]),
#  tensor([7]),
#  tensor([0]),
#  tensor([5]),
#  tensor([6]),
#  tensor([6]),
#  tensor([0]),
#  tensor([4]),
#  tensor([8]),
#  tensor([6]),
#  tensor([6]),
#  tensor([1]),
#  tensor([5]),
#  tensor([7]),
#  tensor([3]),
#  tensor([0]),
#  tensor([3]),
#  tensor([0]),
#  tensor([2]),
#  tensor([5]),
#  tensor([1]),
#  tensor([0]),
#  tensor([1]),
#  tensor([6]),
#  tensor([2]),
#  tensor([4]),
#  tensor([1]),
#  tensor([6]),
#  tensor([3]),
#  tensor([4]),
#  tensor([3]),
#  tensor([8]),
#  tensor([8]),
#  tensor([7]),
#  tensor([6]),
#  tensor([2]),
#  tensor([5]),
#  tensor([8]),
#  tensor([4]),
#  tensor([5]),
#  tensor([4]),
#  tensor([2]),
#  tensor([8]),
#  tensor([2]),
#  tensor([8]),
#  tensor([2]),
#  tensor([1]),
#  tensor([2]),
#  tensor([7]),
#  tensor([5]),
#  tensor([5]),
#  tensor([8]),
#  tensor([4]),
#  tensor([3]),
#  tensor([3]),
#  tensor([6]),
#  tensor([6]),
#  tensor([5]),
#  tensor([4]),
#  tensor([3]),
#  tensor([2]),
#  tensor([8]),
#  tensor([6]),
#  tensor([5]),
#  tensor([1]),
#  tensor([8]),
#  tensor([1]),
#  tensor([1]),
#  tensor([1]),
#  tensor([0]),
#  tensor([2]),
#  tensor([7]),
#  tensor([8]),
#  tensor([7]),
#  tensor([2]),
#  tensor([3]),
#  tensor([1]),
#  tensor([1]),
#  tensor([8]),
#  tensor([3]),
#  tensor([5]),
#  tensor([3]),
#  tensor([0]),
#  tensor([6]),
#  tensor([0]),
#  tensor([8]),
#  tensor([5]),
#  tensor([2]),
#  tensor([1]),
#  tensor([0]),
#  tensor([3]),
#  tensor([4]),
#  tensor([3]),
#  tensor([1]),
#  tensor([5]),
#  tensor([4]),
#  tensor([5]),
#  tensor([4]),
#  tensor([8]),
#  tensor([2]),
#  tensor([1]),
#  tensor([2]),
#  tensor([3]),
#  tensor([3]),
#  tensor([5]),
#  tensor([1]),
#  tensor([2]),
#  tensor([3]),
#  tensor([3]),
#  tensor([1]),
#  tensor([2]),
#  tensor([4]),
#  tensor([7]),
#  tensor([6]),
#  tensor([2]),
#  tensor([7]),
#  tensor([4]),
#  tensor([7]),
#  tensor([1]),
#  tensor([4]),
#  tensor([7]),
#  tensor([8]),
#  tensor([8]),
#  tensor([8]),
#  tensor([1]),
#  tensor([0]),
#  tensor([2]),
#  tensor([7]),
#  tensor([7]),
#  tensor([8]),
#  tensor([5]),
#  tensor([0]),
#  tensor([8]),
#  tensor([2]),
#  tensor([7]),
#  tensor([2]),
#  tensor([2]),
#  tensor([2]),
#  tensor([8]),
#  tensor([6]),
#  tensor([4]),
#  tensor([8]),
#  tensor([6]),
#  tensor([2]),
#  tensor([3]),
#  tensor([0]),
#  tensor([8]),
#  tensor([8]),
#  tensor([7]),
#  tensor([0]),
#  tensor([4]),
#  tensor([2]),
#  tensor([8]),
#  tensor([2]),
#  tensor([6]),
#  tensor([1]),
#  tensor([7]),
#  tensor([3]),
#  tensor([1]),
#  tensor([1]),
#  tensor([4]),
#  tensor([4]),
#  tensor([8]),
#  tensor([6]),
#  tensor([6]),
#  tensor([7]),
#  tensor([4]),
#  tensor([8]),
#  tensor([7]),
#  tensor([2]),
#  tensor([5]),
#  tensor([4]),
#  tensor([0]),
#  tensor([7]),
#  tensor([3]),
#  tensor([4]),
#  tensor([3]),
#  tensor([0]),
#  tensor([3]),
#  tensor([8]),
#  tensor([6]),
#  tensor([2]),
#  tensor([4]),
#  tensor([0]),
#  tensor([2]),
#  tensor([0]),
#  tensor([3]),
#  tensor([5]),
#  tensor([6]),
#  tensor([2]),
#  tensor([2]),
#  tensor([5]),
#  tensor([4]),
#  tensor([5]),
#  tensor([2]),
#  tensor([4]),
#  tensor([1]),
#  tensor([1]),
#  tensor([0]),
#  tensor([1]),
#  tensor([4]),
#  tensor([3]),
#  tensor([8]),
#  tensor([4]),
#  tensor([8]),
#  tensor([4]),
#  tensor([7]),
#  tensor([7]),
#  tensor([8]),
#  tensor([0]),
#  tensor([7]),
#  tensor([0]),
#  tensor([0]),
#  tensor([2]),
#  tensor([4]),
#  tensor([1]),
#  tensor([0]),
#  tensor([8]),
#  tensor([2]),
#  tensor([1]),
#  tensor([6]),
#  tensor([8]),
#  tensor([8]),
#  tensor([3]),
#  tensor([8]),
#  tensor([4]),
#  tensor([2]),
#  tensor([6]),
#  tensor([5]),
#  tensor([5]),
#  tensor([2]),
#  tensor([1]),
#  tensor([0]),
#  tensor([1]),
#  tensor([7]),
#  tensor([0]),
#  tensor([6]),
#  tensor([7]),
#  tensor([3]),
#  tensor([2]),
#  tensor([4]),
#  tensor([4]),
#  tensor([6]),
#  tensor([6]),
#  tensor([4]),
#  tensor([5]),
#  tensor([2]),
#  tensor([0]),
#  tensor([5]),
#  tensor([5]),
#  tensor([0]),
#  tensor([7]),
#  tensor([0]),
#  tensor([5]),
#  tensor([5]),
#  tensor([4]),
#  tensor([0]),
#  tensor([3]),
#  tensor([1]),
#  tensor([0]),
#  tensor([3]),
#  tensor([8]),
#  tensor([4]),
#  tensor([6]),
#  tensor([5]),
#  tensor([2]),
#  tensor([8]),
#  tensor([4]),
#  tensor([7]),
#  tensor([0]),
#  tensor([2]),
#  tensor([5]),
#  tensor([7]),
#  tensor([8]),
#  tensor([4]),
#  tensor([2]),
#  tensor([1]),
#  tensor([2]),
#  tensor([3]),
#  tensor([2]),
#  tensor([3]),
#  tensor([5]),
#  tensor([0]),
#  tensor([7]),
#  tensor([2])]

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
lw=2
n_classes = 9
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 3
#       1 import sklearn.metrics as metrics
# ----> 3 fpr, tpr, threshold = metrics.roc_curve(y_test, predicted_classes)
#       4 roc_auc = metrics.auc(fpr, tpr)
#       6 # method I: plt
#
# File ~/anaconda3/envs/gnn/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/anaconda3/envs/gnn/lib/python3.11/site-packages/sklearn/metrics/_ranking.py:1094, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     992 @validate_params(
#     993     {
#     994         "y_true": ["array-like"],
#    (...)
#    1003     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1004 ):
#    1005     """Compute Receiver operating characteristic (ROC).
#    1006
#    1007     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1092     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1093     """
# -> 1094     fps, tps, thresholds = _binary_clf_curve(
#    1095         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1096     )
#    1098     # Attempt to drop thresholds corresponding to points in between and
#    1099     # collinear with other points. These are always suboptimal and do not
#    1100     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1105     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1106     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1107     if drop_intermediate and len(fps) > 2:
#
# File ~/anaconda3/envs/gnn/lib/python3.11/site-packages/sklearn/metrics/_ranking.py:803, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     801 y_type = type_of_target(y_true, input_name="y_true")
#     802 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
# --> 803     raise ValueError("{0} format is not supported".format(y_type))
#     805 check_consistent_length(y_true, y_score, sample_weight)
#     806 y_true = column_or_1d(y_true)
#
# ValueError: multiclass format is not supported

# %%
import torch

# Save:
torch.save(model.state_dict(), 'model_path.pt')

# Load:
model1 = GCN(50,9)  # Initialize your model architecture
model1.load_state_dict(torch.load('model_path.pt'))
model1.eval()  # Set in evaluation mode
# Out:
# GCN(
#   (conv1): GCNConv(50, 128)
#   (conv2): GCNConv(128, 64)
#   (classifier): Linear(in_features=64, out_features=9, bias=True)
# )

# %%
model1.eval()  # Set model to evaluation mode
predictions = []

with torch.no_grad():
    for data in unseen_loader:
        data = data.to(device)
        output = model1(data)
        predicted_class = torch.argmax(output, dim=1)
        predictions.extend(predicted_class.cpu().numpy().tolist())

# %%
predictions
# Out:
# [0, 1, 2, 3]

# %%
# Example single graph data
single_graph = Data(...)  # Replace with your actual graph data

# Move data to device
single_graph = single_graph.to(device)

# Function for prediction on a single graph
def predict_single(graph):
    model.eval()  # Set model to evaluation mode

    with torch.no_grad():
        output = model(graph)
        predicted_class = torch.argmax(output, dim=1)

    return predicted_class.item()  # Convert tensor to Python scalar

# Get prediction
predicted_class = predict_single(single_graph)
print(predicted_class)
